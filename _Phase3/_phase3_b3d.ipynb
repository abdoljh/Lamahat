# %%
# Script source: GitHub repo
import os
import shutil

github_url_path = "https://github.com/abdoljh/Lamahat/tree/main/_Phase3"

# Extract the base GitHub repository URL and the subfolder path
def parse_github_path(url):
    parts = url.split('/tree/main/')
    repo_url = parts[0]
    subfolder_path = parts[1] if len(parts) > 1 else ''
    # Add .git for cloning
    repo_url_for_clone = repo_url + '.git'
    return repo_url_for_clone, subfolder_path

repo_url_for_clone, subfolder_path_in_repo = parse_github_path(github_url_path)

repo_name = repo_url_for_clone.split('/')[-1].replace('.git', '')
temp_clone_dir = os.path.join('/tmp', repo_name)
dest_dir_colab = '/content'

print(f"Cloning repository: {repo_url_for_clone}")
print(f"Target subfolder in repo: {subfolder_path_in_repo}")

# Clean up any previous clone to avoid issues
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Removed existing temporary directory: {temp_clone_dir}")

# Clone the repository
clone_command = f"git clone {repo_url_for_clone} {temp_clone_dir}"
print(f"Executing: {clone_command}")
os.system(clone_command)

# Check if cloning was successful
if not os.path.exists(temp_clone_dir):
    print(f"Error: Failed to clone repository {repo_url_for_clone}")
else:
    source_dir_to_copy = os.path.join(temp_clone_dir, subfolder_path_in_repo)
    if not os.path.exists(source_dir_to_copy):
        print(f"Error: Subfolder '{subfolder_path_in_repo}' not found in cloned repository at '{source_dir_to_copy}'")
    else:
        print(f"Source directory to copy: {source_dir_to_copy}")
        print(f"Copying contents of '{source_dir_to_copy}' directly into '{dest_dir_colab}'.")

        # Define directories to skip
        dirs_to_skip = ['artifacts', 'review']

        try:
            for item in os.listdir(source_dir_to_copy):
                if item in dirs_to_skip:
                    print(f"Skipping directory '{item}' as requested.")
                    continue

                source_item_path = os.path.join(source_dir_to_copy, item)
                dest_item_path = os.path.join(dest_dir_colab, item)

                # If item already exists in destination, remove it to avoid errors
                if os.path.exists(dest_item_path):
                    if os.path.isdir(dest_item_path):
                        shutil.rmtree(dest_item_path)
                        print(f"Removed existing directory '{dest_item_path}'.")
                    else:
                        os.remove(dest_item_path)
                        print(f"Removed existing file '{dest_item_path}'.")

                if os.path.isdir(source_item_path):
                    shutil.copytree(source_item_path, dest_item_path)
                else:
                    shutil.copy2(source_item_path, dest_item_path)
                print(f"Copied '{source_item_path}' to '{dest_item_path}'.")
            print(f"Successfully copied contents of '{source_dir_to_copy}' to '{dest_dir_colab}'.")

        except Exception as e:
            print(f"An error occurred during directory contents copy: {e}")

# Clean up the cloned repository
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Cleaned up temporary clone directory: {temp_clone_dir}")

print("😺 GitHub repo loaded!")
# Out:
# Cloning repository: https://github.com/abdoljh/Lamahat.git
# Target subfolder in repo: _Phase3
# Executing: git clone https://github.com/abdoljh/Lamahat.git /tmp/Lamahat
# Source directory to copy: /tmp/Lamahat/_Phase3
# Copying contents of '/tmp/Lamahat/_Phase3' directly into '/content'.
# Copied '/tmp/Lamahat/_Phase3/_phase3_b3d.ipynb' to '/content/_phase3_b3d.ipynb'.
# Copied '/tmp/Lamahat/_Phase3/my_book_cover_1.jpg' to '/content/my_book_cover_1.jpg'.
# Copied '/tmp/Lamahat/_Phase3/verify_title_card.py' to '/content/verify_title_card.py'.
# Copied '/tmp/Lamahat/_Phase3/my_jafar.jpg' to '/content/my_jafar.jpg'.
# Copied '/tmp/Lamahat/_Phase3/my_book_cover.jpg' to '/content/my_book_cover.jpg'.
# Copied '/tmp/Lamahat/_Phase3/verify_font_discovery.py' to '/content/verify_font_discovery.py'.
# Copied '/tmp/Lamahat/_Phase3/prebuild_assets.py' to '/content/prebuild_assets.py'.
# Copied '/tmp/Lamahat/_Phase3/render_plan.py' to '/content/render_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/diagnose_issue4.py' to '/content/diagnose_issue4.py'.
# Copied '/tmp/Lamahat/_Phase3/phase3' to '/content/phase3'.
# Copied '/tmp/Lamahat/_Phase3/samples' to '/content/samples'.
# Copied '/tmp/Lamahat/_Phase3/sandbox_test.py' to '/content/sandbox_test.py'.
# Copied '/tmp/Lamahat/_Phase3/Phase3.md' to '/content/Phase3.md'.
# Copied '/tmp/Lamahat/_Phase3/temp' to '/content/temp'.
# Copied '/tmp/Lamahat/_Phase3/make_test_png.py' to '/content/make_test_png.py'.
# Copied '/tmp/Lamahat/_Phase3/trim_book_cover.py' to '/content/trim_book_cover.py'.
# Skipping directory 'artifacts' as requested.
# Skipping directory 'review' as requested.
# Copied '/tmp/Lamahat/_Phase3/diagnose_captions.py' to '/content/diagnose_captions.py'.
# Copied '/tmp/Lamahat/_Phase3/output' to '/content/output'.
# Copied '/tmp/Lamahat/_Phase3/verify_user_marked.py' to '/content/verify_user_marked.py'.
# Copied '/tmp/Lamahat/_Phase3/CLAUDE.md' to '/content/CLAUDE.md'.
# Copied '/tmp/Lamahat/_Phase3/my_book.jpg' to '/content/my_book.jpg'.
# Copied '/tmp/Lamahat/_Phase3/INSTALL.md' to '/content/INSTALL.md'.
# Copied '/tmp/Lamahat/_Phase3/audit_plan.py' to '/content/audit_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/fonts' to '/content/fonts'.
# Copied '/tmp/Lamahat/_Phase3/phase3_run.py' to '/content/phase3_run.py'.
# Successfully copied contents of '/tmp/Lamahat/_Phase3' to '/content'.
# Cleaned up temporary clone directory: /tmp/Lamahat
# 😺 GitHub repo loaded!

# %%
# Smoke rendering
from pathlib import Path
from phase3.typography_common import TypographySpec
from phase3.typography import render
import os

# Ensure the target directory exists
output_dir = '/content/temp'
os.makedirs(output_dir, exist_ok=True)

rendered_files_expected = []
for fam in ("A", "B", "C"):
    for tpl in ("title_card", "section_mark", "pull_quote", "name_reveal", "date_stamp"):
        spec = TypographySpec(
            template=tpl, family=fam,
            #text="مذكرات جعفر العسكري",
            text = "مُذَكِّراتُ جَعْفَرِ العَسْكَرِيِّ",
            subtitle="١٨٨٥ - ١٩٣٦",
            width=1920, height=1080,
        )
        file_path = Path(f"{output_dir}/typo_{fam}_{tpl}.png")
        render(spec, file_path)
        rendered_files_expected.append(file_path)

print("💨 Typography examples rendering process completed.")

# Verification step
print(f"\nVerifying files in '{output_dir}':")
found_files_actual = []
for f_expected in rendered_files_expected:
    if f_expected.exists():
        found_files_actual.append(f_expected.name)
        print(f"  ✅ Found: {f_expected.name}")
    else:
        print(f"  ❌ NOT found: {f_expected.name}")

if not found_files_actual:
    print(f"No rendered image files were found in '{output_dir}'.")
    print("This suggests an issue with the `render` function from `phase3.typography` not creating the files as expected, or writing them to a different location.")
else:
    print(f"\nSuccessfully found {len(found_files_actual)} rendered files.")
# Out:
# 💨 Typography examples rendering process completed.
#
# Verifying files in '/content/temp':
#   ✅ Found: typo_A_title_card.png
#   ✅ Found: typo_A_section_mark.png
#   ✅ Found: typo_A_pull_quote.png
#   ✅ Found: typo_A_name_reveal.png
#   ✅ Found: typo_A_date_stamp.png
#   ✅ Found: typo_B_title_card.png
#   ✅ Found: typo_B_section_mark.png
#   ✅ Found: typo_B_pull_quote.png
#   ✅ Found: typo_B_name_reveal.png
#   ✅ Found: typo_B_date_stamp.png
#   ✅ Found: typo_C_title_card.png
#   ✅ Found: typo_C_section_mark.png
#   ✅ Found: typo_C_pull_quote.png
#   ✅ Found: typo_C_name_reveal.png
#   ✅ Found: typo_C_date_stamp.png
#
# Successfully found 15 rendered files.

# %%
# Zip typography images
import os
import zipfile

image_dir = '/content/temp'
zip_filename = 'typography_images.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    if os.path.exists(image_dir):
        for root, dirs, files in os.walk(image_dir):
            for file in files:
                if file.endswith('.png'): # Only zip PNG images
                    file_path = os.path.join(root, file)
                    # Add file to zip, preserving directory structure relative to 'image_dir'
                    zipf.write(file_path, os.path.relpath(file_path, image_dir))
                    files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing:")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print(f"  (No .png files found in '{image_dir}' to zip.)")
# Out:
# 🤐 Successfully created 'typography_images.zip' containing:
#   - /content/temp/typo_C_pull_quote.png
#   - /content/temp/typo_A_title_card.png
#   - /content/temp/typo_B_name_reveal.png
#   - /content/temp/typo_A_pull_quote.png
#   - /content/temp/typo_B_section_mark.png
#   - /content/temp/typo_B_date_stamp.png
#   - /content/temp/typo_A_name_reveal.png
#   - /content/temp/typo_B_title_card.png
#   - /content/temp/typo_A_section_mark.png
#   - /content/temp/typo_C_title_card.png
#   - /content/temp/typo_B_pull_quote.png
#   - /content/temp/typo_C_date_stamp.png
#   - /content/temp/typo_A_date_stamp.png
#   - /content/temp/typo_C_name_reveal.png
#   - /content/temp/typo_C_section_mark.png

# %%
# Verify font discovery (OPTIONAL)
# !python verify_font_discovery.py

# %%
# Check font paths (OPTIONAL)
# !python -c "from phase3.typography import FONT_PATHS; print(FONT_PATHS)"
# print("✅ Pre-testingvthe discovery of Amiri fonts completed!")

# %%
# !pip install anthropic
print("✴️ Anthropic installed!")
# Out:
# Collecting anthropic
#   Downloading anthropic-0.104.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.104.1-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.0/833.0 kB 11.0 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.104.1
# ✴️ Anthropic installed!

# %%
# !pip install whisperx openai-whisper
# print("✅ whisperx and openai-whisper installed!")

# %%
# !pip install arabic-reshaper python-bidi
# print("✅ Arabic_reshaper and python-bidi installed!")

# %%
print("Retrieving the Anthropic & Pexels API keys ...")
from google.colab import userdata
import os

# Retrieve the Anthropic API key from Colab Secrets
anthropic_api_key = userdata.get('ANTHROPIC_API_KEY')
pexels_api_key = userdata.get('PEXELS_API_KEY')

# Set it as an environment variable for phase3_run.py to use
if anthropic_api_key:
    os.environ['ANTHROPIC_API_KEY'] = anthropic_api_key
    print("🔑 Anthropic API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: ANTHROPIC_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")

if pexels_api_key:
    os.environ['PEXELS_API_KEY'] = pexels_api_key
    print("🔑 Pexels API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: PEXELS_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")
# Out:
# Retrieving the Anthropic & Pexels API keys ...
# 🔑 Anthropic API key loaded from secrets and set as environment variable.
# 🔑 Pexels API key loaded from secrets and set as environment variable.

# %%
# Confirm alignment works (interpolation backend — no install needed)
# !python phase3_run.py \
    --script samples/al_askari_script.txt \
    --audio output/al_askari_audio.mp3 \
    --align-only \
    --align-backend interpolated

print("✅ Confirming alignment completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,039 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
# Backend: interpolated
#
# ── Running alignment ──────────────────────────────────────────────
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#
#   Aligned 653 words in 0.0 s
#   Backend used: interpolated
#
# ── First 30 word timings ──────────────────────────────────────────
#      0.00s →    0.71s   (0.71s)   مذكرات
#      0.71s →    1.18s   (0.47s)   جعفر
#      1.18s →    2.01s   (0.83s)   العسكري
#      2.01s →    2.37s   (0.36s)   رجل
#      2.37s →    2.84s   (0.47s)   واحد
#      2.84s →    3.20s   (0.36s)   حمل
#      3.20s →    3.91s   (0.71s)   سلاحاً
#      3.91s →    4.14s   (0.24s)   من
#      4.14s →    4.50s   (0.36s)   أجل
#      4.50s →    5.09s   (0.59s)   تحرير
#      5.09s →    5.68s   (0.59s)   وطنه،
#      5.68s →    6.16s   (0.47s)   لكنه
#      6.16s →    6.87s   (0.71s)   اكتشفَ
#      6.87s →    7.34s   (0.47s)   أنَّ
#      7.34s →    7.81s   (0.47s)   أشرس
#      7.81s →    8.64s   (0.83s)   الأعداء
#      8.64s →    8.88s   (0.24s)   قد
#      8.88s →    9.59s   (0.71s)   يكونون
#      9.59s →    9.83s   (0.24s)   من
#      9.83s →   10.30s   (0.47s)   داخل
#     10.30s →   10.89s   (0.59s)   صفوفك
#     10.89s →   11.25s   (0.36s)   هذه
#     11.25s →   11.72s   (0.47s)   ليست
#     11.72s →   12.31s   (0.59s)   رواية
#     12.31s →   12.78s   (0.47s)   خيال
#     12.78s →   13.61s   (0.83s)   تاريخي،
#     13.61s →   13.85s   (0.24s)   بل
#     13.85s →   14.56s   (0.71s)   شهادةٌ
#     14.56s →   15.15s   (0.59s)   حيّةٌ
#     15.15s →   15.39s   (0.24s)   من
#   … and 623 more
#
# Word timings → output/word_timings.json
# ✅ Confirming alignment completed!

# %%
# Step 1: plan as before — produces output/al_askari_plan_v2.json
# Regenerate the plan with the fixes
# !python phase3_run.py \
    --script  samples/al_askari_script.txt \
    --audio   output/al_askari_audio.mp3 \
    --book-title "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --plan-only \
    --save-plan output/al_askari_plan_v2.json

print("✅ Regenerating the plan completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,039 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
#
# ── Step 1: Forced alignment ───────────────────────────────────────
# WARNING  phase3.align  Backend whisperx failed: No module named 'whisperx'
# WARNING  phase3.align  Backend whisper failed: No module named 'whisper'
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#   653 words aligned via interpolated (0.0s)
#
# ── Step 2: AI shot planner ────────────────────────────────────────
# INFO  phase3.plan  Calling claude-sonnet-4-6 for shot plan (target=65 shots, 4.5s avg, 391.0s total)
# INFO  httpx  HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO  phase3.plan  Normalised 4 shot(s) with conflicting fields
# INFO  phase3.plan  Clipping shot 383.66-391.00s to 391.00s (audio end)
# INFO  phase3.plan  Merged 1 adjacent identical shot(s) — final plan 67 shots
# INFO  phase3.plan  Plan produced: 67 shots
#   67 shots planned in 126.4s
#
# Plan: 67 shots, 391.0s total
# ────────────────────────────────────────────────────────────────────────────────────────────
# Visuals: typography:25  broll:13  archive:9  portrait:6  location:5  section_mark:4  object:3  title_card:2
# ────────────────────────────────────────────────────────────────────────────────────────────
#     1. [  opening]   0.00-  3.91s ( 3.9s) title_card     static_hold
#     2. [  opening]   3.91-  8.64s ( 4.7s) typography     static_hold   "رجل واحد حمل سلاحاً من أجل تحرير وطنه"
#     3. [  opening]   8.64- 13.61s ( 5.0s) typography     static_hold   "أشرس الأعداء قد يكونون من داخل صفوفك"
#     4. [  opening]  13.61- 18.35s ( 4.7s) archive        slow_push     Ottoman Empire Arab officers historical photograph 1900s
#     5. [  opening]  18.35- 23.44s ( 5.1s) portrait       static_hold   Jafar al-Askari Iraqi officer portrait historical
#     6. [  opening]  23.44- 28.88s ( 5.4s) typography     static_hold   "سجلاً دقيقاً عن حقبة لم يعرفها سوى من عاشوها"
#     7. [  opening]  28.88- 33.97s ( 5.1s) broll          slow_pull     Ottoman Empire collapse historical documentary footage 1918
#     8. [  opening]  33.97- 40.13s ( 6.2s) typography     static_hold   "كيف يصنع العسكري ثورة؟"
#     9. [  opening]  40.13- 45.10s ( 5.0s) broll          pan_right     Arab nationalist movement historical photo Middle East 1916
#    10. [  opening]  45.10- 50.78s ( 5.7s) typography     static_hold   "هذه المذكرات النادرة والمهمة"
#    11. [  opening]  50.78- 55.28s ( 4.5s) section_mark   static_hold
#    12. [  opening]  55.28- 59.54s ( 4.3s) location       slow_push     Mosul Iraq historical photograph 1900s Ottoman era
#    13. [  opening]  59.54- 63.69s ( 4.1s) archive        slow_push     Ottoman military academy Constantinople Istanbul 1900s photo
#    14. [  opening]  63.69- 69.25s ( 5.6s) typography     static_hold   "عبوراً من عالم تقليدي إلى آفاق حديثة"
#    15. [  opening]  69.25- 75.05s ( 5.8s) location       pan_left      Constantinople Istanbul 1904 historical Ottoman city panoram
#    16. [  opening]  75.05- 80.62s ( 5.6s) archive        slow_push     German military training Ottoman officers 1900s archive phot
#    17. [  opening]  80.62- 85.94s ( 5.3s) broll          ken_burns     young Arab officers group portrait Ottoman military academy
#    18. [  opening]  85.94- 91.74s ( 5.8s) typography     static_hold   "جميعهم يحملون حلماً واحداً"
#    19. [  opening]  91.74- 97.19s ( 5.4s) portrait       static_hold   Mahmud Shawkat Pasha Ottoman general portrait historical
#    20. [  opening]  97.19-103.23s ( 6.0s) broll          slow_push     Ottoman army reform modernisation early 20th century archive
#    21. [  opening] 103.23-109.26s ( 6.0s) typography     static_hold   "الإصلاح الحقيقي لا يتوقف على التسليح والتَّكْتِيكا"
#    22. [  opening] 109.26-115.18s ( 5.9s) broll          slow_pull     Ottoman Empire intellectual officers reading modernisation r
#    23. [  opening] 115.18-121.57s ( 6.4s) typography     static_hold   "تحرير العقول والمؤسسات من القيود الاستبدادية"
#    24. [  opening] 121.57-127.02s ( 5.4s) archive        ken_burns     Arab world education military modernisation early 20th centu
#    25. [  opening] 127.02-133.65s ( 6.6s) typography     static_hold   "آمن أن التعليم والجيش الحديث يمكنهما أن يكونا أداة"
#    26. [  opening] 133.65-141.34s ( 7.7s) broll          slow_push     Arab world historical map Middle East early 1900s Ottoman te
#    27. [  opening] 141.34-146.20s ( 4.9s) section_mark   static_hold
#    28. [  opening] 146.20-150.81s ( 4.6s) location       slow_push     Istanbul Constantinople political underground 1908 Ottoman c
#    29. [  opening] 150.81-156.38s ( 5.6s) archive        slow_push     Committee Union Progress CUP Ottoman secret society 1908 arc
#    30. [  opening] 156.38-163.24s ( 6.9s) typography     static_hold   "انقلابات ومكائد تحاك في كل زاوية"
#    31. [  opening] 163.24-168.21s ( 5.0s) archive        fast_push     1908 Young Turk Revolution Ottoman Sultan Abdulhamid II depo
#    32. [  opening] 168.21-175.32s ( 7.1s) portrait       static_hold   Jafar al-Askari young officer historical portrait 1908
#    33. [  opening] 175.32-180.64s ( 5.3s) typography     static_hold   "كيف يمكن لقوة عسكرية منظمة أن تغيّر مسار دولة بأكم"
#    34. [  opening] 180.64-186.44s ( 5.8s) broll          slow_pull     Ottoman Empire political corruption new regime 1909 archive
#    35. [  opening] 186.44-192.84s ( 6.4s) typography     static_hold   "النظام الجديد حمل فساداً من نوع آخر"
#    36. [  opening] 192.84-199.58s ( 6.7s) broll          slow_push     Arab officer inner conflict Ottoman loyalty nationalism 1910
#    37. [  opening] 199.58-206.57s ( 7.0s) typography     static_hold   "كيف يتآكل الحلم بسبب الأنانية والمكائد السياسية"
#    38. [  opening] 206.57-213.55s ( 7.0s) portrait       static_hold   Jafar al-Askari military uniform portrait historical Iraq
#    39. [  opening] 213.55-220.54s ( 7.0s) typography     static_hold   "صراع الضميرين — ضمير الجندي الوفي لدولته وضمير الو"
#    40. [  opening] 220.54-226.10s ( 5.6s) broll          pan_right     Arab nationalism movement early 20th century historical phot
#    41. [  opening] 226.10-229.77s ( 3.7s) section_mark   static_hold
#    42. [  opening] 229.77-234.03s ( 4.3s) archive        fast_push     Balkan Wars 1912 1913 Ottoman army historical archive photog
#    43. [  opening] 234.03-239.00s ( 5.0s) typography     static_hold   "لم يَعُدْ هناك متسعٌ للنظرياتِ والأحلامْ"
#    44. [  opening] 239.00-245.04s ( 6.0s) broll          slow_push     World War One Middle East desert campaign 1916 historical fo
#    45. [  opening] 245.04-251.20s ( 6.2s) typography     static_hold   "هل يبقى جندياً وفياً للدولةِ العثمانيةِ المتداعية،"
#    46. [  opening] 251.20-257.35s ( 6.2s) location       pan_left      Libya North Africa Senussi movement desert 1915 World War On
#    47. [  opening] 257.35-262.56s ( 5.2s) archive        slow_push     Senussi movement North Africa Ottoman allied forces 1915 arc
#    48. [  opening] 262.56-268.01s ( 5.4s) location       pan_right     Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal milit
#    49. [  opening] 268.01-275.58s ( 7.6s) typography     static_hold   "القرارات الصعبة التي اتخذها، والثمن الذي دفعه على "
#    50. [  opening] 275.58-281.38s ( 5.8s) broll          slow_push     Arab Revolt 1916 desert cavalry campaign historical document
#    51. [  opening] 281.38-287.30s ( 5.9s) typography     static_hold   "اختباراً حقيقياً لكل ما آمن به وعمل من أجله"
#    52. [  opening] 287.30-293.81s ( 6.5s) archive        ken_burns     Jafar al-Askari Faisal I Arab officers Iraq 1920 historical
#    53. [  closing] 293.81-298.07s ( 4.3s) section_mark   static_hold
#    54. [  closing] 298.07-302.81s ( 4.7s) object         slow_push     old Arabic memoir book open pages historical document close-
#    55. [  closing] 302.81-309.56s ( 6.7s) typography     static_hold   "دعوة للتأمل العميق حول طبيعة الولاء والوطنية"
#    56. [  closing] 309.56-315.24s ( 5.7s) broll          slow_pull     historical crossroads old and new world change transformatio
#    57. [  closing] 315.24-322.46s ( 7.2s) typography     static_hold   "بين قديم يموت وجديد يولد"
#    58. [  closing] 322.46-328.26s ( 5.8s) portrait       static_hold   Najda Fathi Safwat Iraqi historian scholar portrait
#    59. [  closing] 328.26-334.65s ( 6.4s) typography     static_hold   "فرصة نادرة للدخول إلى عقل ضابط عاش أهم لحظات التار"
#    60. [  closing] 334.65-340.93s ( 6.3s) object         slow_push     Jafar al-Askari memoirs book cover Arabic edition close-up
#    61. [  closing] 340.93-348.74s ( 7.8s) broll          ken_burns     historical maps documents letters manuscripts Arabic archive
#    62. [  closing] 348.74-356.20s ( 7.5s) typography     static_hold   "نقاشاً صريحاً عن الفساد والخيانة والطموح والتضحية"
#    63. [  closing] 356.20-363.89s ( 7.7s) typography     static_hold   "رجل تَرَدَّدَ وتألَّمَ واختارَ بشجاعة"
#    64. [  closing] 363.89-370.52s ( 6.6s) portrait       static_hold   Jafar al-Askari Iraqi prime minister politician historical p
#    65. [  closing] 370.52-377.51s ( 7.0s) typography     static_hold   "فهم حاضرنا لا يتحقق إلا بفهم عميق لماضينا"
#    66. [  closing] 377.51-383.66s ( 6.2s) object         slow_push     Arabic book memoir historical elegant cover typography close
#    67. [  closing] 383.66-391.00s ( 7.3s) title_card     static_hold
#
# Shot plan → output/al_askari_plan_v2.json
# Word timings → output/word_timings.json
# ✅ Regenerating the plan completed!

# %%
# Audit it
# !python audit_plan.py output/al_askari_plan_v2.json
# Expect: ~43 shots, <10% auto-split

print("✅ Audit completed!")
# Out:
# ======================================================================
# PLAN AUDIT
# ======================================================================
#
# Total shots:        67
# Plan timeline:      0.00s → 391.00s (391.0s)
# Average shot:       5.84s
# Range:              3.67s – 7.81s
#
# ✓  No gaps or overlaps
#
# Visual types:
#    typography      25 (  37%) ███████████
#    broll           13 (  19%) █████
#    archive          9 (  13%) ████
#    portrait         6 (   9%) ██
#    location         5 (   7%) ██
#    section_mark     4 (   6%) █
#    object           3 (   4%) █
#    title_card       2 (   3%)
#
# Motion types:
#    static_hold     37 (  55%) ████████████████
#    slow_push       15 (  22%) ██████
#    slow_pull        4 (   6%) █
#    ken_burns        4 (   6%) █
#    pan_right        3 (   4%) █
#    pan_left         2 (   3%)
#    fast_push        2 (   3%)
#
# Section coverage:
#    opening         52 shots
#    closing         15 shots
#
# ✓  Auto-split shots: 1/67 (1%) from 1 original(s)
#      Implied original Sonnet shot count: 67
#
# Typography texts: 31 unique (31 occurrences after splits)
#    Word count: min=3, max=13, avg=7.4
#    Templates: chapter_heading:6, pull_quote:25
#
#
# Search queries: 36 non-empty, avg 8.4 words
#    ✓ Bare (1–2 words): 0 (none — good specificity)
#
# ======================================================================
# ✅ Audit completed!

# %%
# !python trim_book_cover.py my_book.jpg
# Out:
# Source: my_book.jpg  864×1217  aspect 0.710
# Detected bbox: x [0, 863]  y [0, 1216]  (863×1216)
# With 3.0% margin: 864×1217  aspect 0.710
# Saved: my_book_trimmed.jpg  (322,182 bytes)
#
# Next:
#   python prebuild_assets.py ... --book-cover my_book_trimmed.jpg --book-cover-fit contain

# %%
import os

# Step 2 (NEW): prebuild — run every source, score every candidate,
# write a review dossier.  No video render.
# !python prebuild_assets.py \
    --plan          output/al_askari_plan_v2.json \
    --script        samples/al_askari_script.txt \
    --book-title    "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --anthropic-key "$ANTHROPIC_API_KEY" \
    --pexels-key    "$PEXELS_API_KEY" \
    --review-dir    output/review/ \
    --character-portrait my_jafar.jpg \
    --book-cover my_book_trimmed.jpg \
    --book-cover-fit contain \
    --book-cover-align left

print("🧩 Prebuild completed!")
# Out:
# INFO    phase3.prebuild  Loaded plan: 67 shots
# INFO    phase3.prebuild  Image-needing shots: 36 (the rest are typography)
# INFO    phase3.prebuild  Pinned portrait copied → /content/output/review/overrides/character.jpg
# INFO    phase3.prebuild  Book cover copied → /content/output/review/overrides/book_cover.jpg
# INFO    phase3.prebuild  Shot 4/archive: query='Ottoman Empire Arab officers historical photograph 1900s' duration=4.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire Arab officers historical photograph 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire Arab officers historical photograph 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire Arab officers historical photograph 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire Arab officers historical photograph 1900s'
# INFO    phase3.sources.vision  Vision 1/3/3  Close-up of the ornate dome ceiling in H  — Stunning Ottoman-era architectural photography with Islamic
# INFO    phase3.sources.vision  Vision 1/3/3  Turkish warrior in armor riding a horse,  — Modern Turkish flag with historical armor evokes Ottoman era
# INFO    phase3.sources.vision  Vision 2/3/3  Explore the intricate stone carvings and  — Authentic Ottoman-era architectural detail from correct peri
# INFO    phase3.sources  Shot 4: best=Explore the intricate stone carvings and ornate de (score 8)
# INFO    phase3.prebuild  Shot 5/portrait: query='Jafar al-Askari Iraqi officer portrait historical' duration=5.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi officer portrait historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi officer portrait historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi officer portrait historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi officer portrait historical'
# INFO    phase3.sources.vision  Vision 1/3/2  Man in a tuxedo smiling indoors in a lux  — Modern formal portrait with period-appropriate styling, but
# INFO    phase3.sources.vision  Vision 1/2/2  A stylish businessman with a briefcase e  — Modern staged scene with formal Iraqi officer aesthetic and
# INFO    phase3.sources.vision  Vision 3/3/3  A man in period military costume poses i  — Authentic period military uniform with ornate gold epaulette
# INFO    phase3.sources  Shot 5: best=A man in period military costume poses in an urban (score 9)
# INFO    phase3.prebuild  Shot 7/broll: query='Ottoman Empire collapse historical documentary footage 1918' duration=5.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire collapse historical documentary footage 1918'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire collapse historical documentary footage 1918'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire collapse historical documentary footage 1918'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire collapse historical documentary footage 1918'
# INFO    phase3.sources.vision  Vision 2/3/2  Stunning aerial view of Topkapi Palace,   — Aerial of Ottoman-era palace complex in Istanbul region show
# INFO    phase3.sources.vision  Vision 2/3/3  Exquisite ornate entrance gate of Dolmab  — Ottoman architectural grandeur from the era, excellently com
# INFO    phase3.sources.vision  Vision 2/3/3  Ornate interior of Hagia Sophia with its  — Hagia Sophia interior is architecturally Ottoman-era and vis
# INFO    phase3.sources  Shot 7: best=Exquisite ornate entrance gate of Dolmabahçe Palac (score 8)
# INFO    phase3.prebuild  Shot 9/broll: query='Arab nationalist movement historical photo Middle East 1916' duration=5.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab nationalist movement historical photo Middle East 1916'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab nationalist movement historical photo Middle East 1916'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab nationalist movement historical photo Middle East 1916'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab nationalist movement historical photo Middle East 1916'
# INFO    phase3.sources.vision  Vision 1/2/2  Protester passionately waves Palestinian  — Modern Palestinian flag protest scene; geographically releva
# INFO    phase3.sources.vision  Vision 1/3/3  A large gathering in Syria with people h  — Modern protest rally with Arab nationalist symbolism (green-
# INFO    phase3.sources.vision  Vision 1/2/2  Protesters in Rabat display Palestinian   — Contemporary protest imagery with Palestinian flags; shows A
# INFO    phase3.sources  Shot 9: best=A large gathering in Syria with people holding fla (score 7)
# INFO    phase3.prebuild  Shot 12/location: query='Mosul Iraq historical photograph 1900s Ottoman era' duration=4.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.vision  Vision 2/2/3  Explore an ancient Ottoman cemetery with  — Period-appropriate Ottoman cemetery setting with strong atmo
# INFO    phase3.sources.vision  Vision 2/2/2  Explore the historic ruins of ancient Ba  — Authentic Ottoman-era Iraqi architecture in arid landscape m
# INFO    phase3.sources.vision  Vision 2/3/3  Explore the intricate stone carvings and  — Authentic Ottoman-era architectural detail from Mosul region
# INFO    phase3.sources  Shot 12: best=Explore the intricate stone carvings and ornate de (score 8)
# INFO    phase3.prebuild  Shot 13/archive: query='Ottoman military academy Constantinople Istanbul 1900s photo' duration=4.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman military academy Constantinople Istanbul 1900s photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman military academy Constantinople Istanbul 1900s photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman military academy Constantinople Istanbul 1900s photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman military academy Constantinople Istanbul 1900s photograph'
# INFO    phase3.sources.vision  Vision 2/2/2  Fener Greek High School building in Bala  — Ottoman-era architecture in Istanbul matches period and regi
# INFO    phase3.sources.vision  Vision 2/3/3  Historic Kuleli Military School on the B  — Correct Ottoman architectural style and waterfront location
# INFO    phase3.sources.vision  Vision 2/3/3  Stunning view of the iconic Sultan Ahmed  — Ottoman-era Islamic architecture in Istanbul with authentic
# INFO    phase3.sources  Shot 13: best=Historic Kuleli Military School on the Bosphorus i (score 8)
# INFO    phase3.prebuild  Shot 15/location: query='Constantinople Istanbul 1904 historical Ottoman city panoram' duration=5.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Constantinople Istanbul 1904 historical Ottoman city panorama'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Constantinople Istanbul 1904 historical Ottoman city panorama'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Constantinople Istanbul 1904 historical Ottoman city panorama'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Constantinople Istanbul 1904 historical Ottoman city panorama'
# INFO    phase3.sources.vision  Vision 3/3/3  Scenic view of Istanbul's skyline featur  — Authentic Istanbul skyline with iconic mosques and minarets,
# INFO    phase3.sources.vision  Vision 3/3/3  Scenic view of İstanbul's Galata Tower a  — Perfect match for early 1900s Istanbul/Constantinople panora
# INFO    phase3.sources.vision  Vision 3/2/2  View of Istanbul skyline featuring the i  — Authentic Istanbul panorama with iconic mosques and Golden H
# INFO    phase3.sources  Shot 15: best=Scenic view of Istanbul's skyline featuring histor (score 9)
# INFO    phase3.prebuild  Shot 16/archive: query='German military training Ottoman officers 1900s archive phot' duration=5.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'German military training Ottoman officers 1900s archive photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'German military training Ottoman officers 1900s archive photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'German military training Ottoman officers 1900s archive photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'German military training Ottoman officers 1900s archive photo'
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — Early 1900s military officer on horseback matches era and re
# INFO    phase3.sources.vision  Vision 2/2/2  A captivating vintage army photo in a se  — Period-appropriate archival photograph showing a large milit
# INFO    phase3.sources.vision  Vision 1/3/3  Two soldiers in camouflage advance with   — Modern tactical military photo with excellent composition an
# INFO    phase3.sources  Shot 16: best=Two soldiers in camouflage advance with rifles dur (score 7)
# INFO    phase3.prebuild  Shot 17/broll: query='young Arab officers group portrait Ottoman military academy ' duration=5.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'young Arab officers group portrait Ottoman military academy 1905'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'young Arab officers group portrait Ottoman military academy 1905'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'young Arab officers group portrait Ottoman military academy 1905'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'young Arab officers group portrait Ottoman military academy 1905'
# INFO    phase3.sources.vision  Vision 1/3/2  A group of men in military-style uniform  — Contemporary group portrait of uniformed men in institutiona
# INFO    phase3.sources.vision  Vision 1/3/3  A close-up of uniformed guards in format  — Contemporary military ceremony with formal uniforms and disc
# INFO    phase3.sources.vision  Vision 1/3/2  A military parade of the Chilean Carabin  — Modern military parade in formal uniforms; correct region an
# INFO    phase3.sources  Shot 17: best=A close-up of uniformed guards in formation during (score 7)
# INFO    phase3.prebuild  Shot 19/portrait: query='Mahmud Shawkat Pasha Ottoman general portrait historical' duration=5.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait historical'
# INFO    phase3.sources.vision  Vision 1/3/3  View of the detailed dome and Arabic cal  — Ottoman architectural interior with Islamic calligraphy is h
# INFO    phase3.sources.vision  Vision 1/3/3  Scenic aerial view of İshak Pasha Palace  — Striking Ottoman-era fortress architecture in correct region
# INFO    phase3.sources.vision  Vision 1/3/3  Intricate architectural details of Mesih  — Ottoman-era Islamic architecture is contextually relevant to
# INFO    phase3.sources  Shot 19: best=View of the detailed dome and Arabic calligraphy i (score 7)
# INFO    phase3.prebuild  Shot 20/broll: query='Ottoman army reform modernisation early 20th century archive' duration=6.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman army reform modernisation early 20th century archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman army reform modernisation early 20th century archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman army reform modernisation early 20th century archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman army reform modernisation early 20th century archive'
# INFO    phase3.sources.vision  Vision 3/2/2  Sepia-toned vintage photo of a man in un  — Authentic period photograph of Ottoman-era military officer
# INFO    phase3.sources.vision  Vision 2/3/2  Four soldiers in vintage uniforms with r  — Period military uniform reenactment matches early 20th centu
# INFO    phase3.sources.vision  Vision 2/3/3  A beautiful day view of a mosque in Ista  — Ottoman-era Islamic architecture perfectly evokes early 20th
# INFO    phase3.sources  Shot 20: best=A beautiful day view of a mosque in Istanbul with  (score 8)
# INFO    phase3.prebuild  Shot 22/broll: query='Ottoman Empire intellectual officers reading modernisation r' duration=5.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire intellectual officers reading modernisation reform 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire intellectual officers reading modernisation reform 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire intellectual officers reading modernisation reform 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire intellectual officers reading modernisation reform 1908'
# INFO    phase3.sources.vision  Vision 2/3/2  Smiling adult man sits on a leather sofa  — Modern portrait of man reading in period-styled setting evok
# INFO    phase3.sources.vision  Vision 2/2/2  An empty coffee cup surrounded by open b  — Evokes early 20th-century intellectual life with period book
# INFO    phase3.sources.vision  Vision 2/3/2  Top view of Turkish coffee and books on   — Evokes Ottoman-era intellectual life through styled desk com
# INFO    phase3.sources  Shot 22: best=Smiling adult man sits on a leather sofa enjoying  (score 7)
# INFO    phase3.prebuild  Shot 24/archive: query='Arab world education military modernisation early 20th centu' duration=5.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab world education military modernisation early 20th century archive photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab world education military modernisation early 20th century archive photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab world education military modernisation early 20th century archive photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab world education military modernisation early 20th century archive photograph'
# INFO    phase3.sources.vision  Vision 3/2/2  Sepia-toned vintage photo of a man in un  — Early 20th century military officer on horseback in Arab reg
# INFO    phase3.sources.vision  Vision 2/2/2  A captivating vintage army photo in a se  — Early 20th century archival photographs in appropriate era a
# INFO    phase3.sources.vision  Vision 2/2/3  A nostalgic display of vintage cameras i  — Vintage camera collection evokes early 20th century Arab mod
# INFO    phase3.sources  Shot 24: best=Sepia-toned vintage photo of a man in uniform ridi (score 7)
# INFO    phase3.prebuild  Shot 26/broll: query='Arab world historical map Middle East early 1900s Ottoman te' duration=7.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab world historical map Middle East early 1900s Ottoman territories'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab world historical map Middle East early 1900s Ottoman territories'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab world historical map Middle East early 1900s Ottoman territories'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab world historical map Middle East early 1900s Ottoman territories'
# INFO    phase3.sources.vision  Vision 3/2/2  Colorful world map close-up showing Afri  — Historical map of Middle East/Ottoman territories with appro
# INFO    phase3.sources.vision  Vision 3/3/3  Vibrant map featuring countries in the M  — Vibrant, sharp historical map of Ottoman Empire and Middle E
# INFO    phase3.sources.vision  Vision 3/2/3  Close-up of a vintage map showing the In  — Authentic period map with 'Indian Ocean' visible, depicting
# INFO    phase3.sources  Shot 26: best=Vibrant map featuring countries in the Middle East (score 9)
# INFO    phase3.prebuild  Shot 28/location: query='Istanbul Constantinople political underground 1908 Ottoman c' duration=4.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Istanbul Constantinople political underground 1908 Ottoman coup'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Istanbul Constantinople political underground 1908 Ottoman coup'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Istanbul Constantinople political underground 1908 Ottoman coup'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Istanbul Constantinople political underground 1908 Ottoman coup'
# INFO    phase3.sources.vision  Vision 2/2/2  Fener Greek High School building in Bala  — Ottoman-era architecture in Istanbul matches geographic/temp
# INFO    phase3.sources.vision  Vision 2/3/3  Stunning interior view of Hagia Sophia s  — Ottoman/Islamic architectural interior evokes era and region
# INFO    phase3.sources.vision  Vision 2/3/3  Süleymaniye Mosque minaret framed by sto  — Ottoman-era Istanbul architecture (minaret, mosque) matches
# INFO    phase3.sources  Shot 28: best=Stunning interior view of Hagia Sophia showcasing  (score 8)
# INFO    phase3.prebuild  Shot 29/archive: query='Committee Union Progress CUP Ottoman secret society 1908 arc' duration=5.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Committee Union Progress CUP Ottoman secret society 1908 archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Committee Union Progress CUP Ottoman secret society 1908 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Committee Union Progress CUP Ottoman secret society 1908 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Committee Union Progress CUP Ottoman secret society 1908 archive'
# INFO    phase3.sources.vision  Vision 3/2/3  An old Russian document placed inside an  — Authentic archival document with handwritten notes in Arabic
# INFO    phase3.sources.vision  Vision 0/3/2  Front view of a fire station with a fire  — Modern fire station photograph (2024) bears no relation to O
# INFO    phase3.sources.vision  Vision 1/2/1  Ceramic cup of Turkish coffee with intri  — Ottoman-era decorative teacup relates thematically to early
# INFO    phase3.sources  Shot 29: best=An old Russian document placed inside an archive b (score 8)
# INFO    phase3.prebuild  Shot 31/archive: query='1908 Young Turk Revolution Ottoman Sultan Abdulhamid II depo' duration=5.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for '1908 Young Turk Revolution Ottoman Sultan Abdulhamid II deposed historical photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for '1908 Young Turk Revolution Ottoman Sultan Abdulhamid II deposed historical photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for '1908 Young Turk Revolution Ottoman Sultan Abdulhamid II deposed historical photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for '1908 Young Turk Revolution Ottoman Sultan Abdulhamid II deposed historical photograph'
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze statues of Ottoman military figures, correct era and
# INFO    phase3.sources.vision  Vision 2/3/3  Entrance of the historic Kurşunlu Han in  — Ottoman architecture from the correct era and region (early
# INFO    phase3.sources.vision  Vision 2/3/3  Intricate Ottoman architectural details   — Ottoman architectural detail with calligraphy and gilded orn
# INFO    phase3.sources  Shot 31: best=Entrance of the historic Kurşunlu Han in Manisa, T (score 8)
# INFO    phase3.prebuild  Shot 32/portrait: query='Jafar al-Askari young officer historical portrait 1908' duration=7.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari young officer historical portrait 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari young officer historical portrait 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari young officer historical portrait 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari young officer historical portrait 1908'
# INFO    phase3.sources.vision  Vision 0/2/2  A young man with an Arabian horse in Al-  — Modern portrait of a young man with a horse; unrelated to Ja
# INFO    phase3.sources.vision  Vision 0/2/1  Yemeni groom posing in traditional attir  — Modern costume performance/reenactment with stage setting, n
# INFO    phase3.sources.vision  Vision 2/3/3  A man in period military costume poses i  — Period military costume in urban European setting matches er
# INFO    phase3.sources  Shot 32: best=A man in period military costume poses in an urban (score 8)
# INFO    phase3.prebuild  Shot 34/broll: query='Ottoman Empire political corruption new regime 1909 archive ' duration=5.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire political corruption new regime 1909 archive Istanbul'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire political corruption new regime 1909 archive Istanbul'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire political corruption new regime 1909 archive Istanbul'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire political corruption new regime 1909 archive Istanbul'
# INFO    phase3.sources.vision  Vision 2/3/2  Front view of a traditional Ottoman bath  — Ottoman-era architecture in Istanbul matches period/region o
# INFO    phase3.sources.vision  Vision 2/3/2  Stunning aerial view of Topkapi Palace,   — Aerial view of Topkapi Palace in Istanbul clearly establishe
# INFO    phase3.sources.vision  Vision 2/3/2  Exquisite ornate entrance gate of Dolmab  — Ottoman-era architectural monument from Istanbul fits histor
# INFO    phase3.sources  Shot 34: best=Front view of a traditional Ottoman bathhouse in I (score 7)
# INFO    phase3.prebuild  Shot 36/broll: query='Arab officer inner conflict Ottoman loyalty nationalism 1910' duration=6.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab officer inner conflict Ottoman loyalty nationalism 1910s documentary'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab officer inner conflict Ottoman loyalty nationalism 1910s documentary'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab officer inner conflict Ottoman loyalty nationalism 1910s documentary'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab officer inner conflict Ottoman loyalty nationalism 1910s documentary'
# INFO    phase3.sources.vision  Vision 2/2/3  Police officers in helmets and shields c  — Depicts civil unrest and state authority circa early 20th ce
# INFO    phase3.sources.vision  Vision 2/3/3  The front facade of Istanbul's PTT Museu  — Ottoman-era architecture with Turkish flag and portrait sugg
# INFO    phase3.sources.vision  Vision 2/2/2  Sunlit Turkish flag on Ottoman architect  — Turkish flag and period architecture evoke early 20th-centur
# INFO    phase3.sources  Shot 36: best=The front facade of Istanbul's PTT Museum with Tur (score 8)
# INFO    phase3.prebuild  Shot 38/portrait: query='Jafar al-Askari military uniform portrait historical Iraq' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari military uniform portrait historical Iraq'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari military uniform portrait historical Iraq'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari military uniform portrait historical Iraq'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari military uniform portrait historical Iraq'
# INFO    phase3.sources.vision  Vision 2/3/3  Side profile of a man wearing ornate his  — Authentic Ottoman-era military dress uniform from correct hi
# INFO    phase3.sources.vision  Vision 2/3/3  A man in period military costume poses i  — Well-composed historical military portrait with period unifo
# INFO    phase3.sources.vision  Vision 2/3/3  Portrait of a man in a historical milita  — Authentic Ottoman-era military uniform with period-appropria
# INFO    phase3.sources  Shot 38: best=Side profile of a man wearing ornate historical mi (score 8)
# INFO    phase3.prebuild  Shot 40/broll: query='Arab nationalism movement early 20th century historical phot' duration=5.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab nationalism movement early 20th century historical photograph Middle East'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab nationalism movement early 20th century historical photograph Middle East'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab nationalism movement early 20th century historical photograph Middle East'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab nationalism movement early 20th century historical photograph Middle East'
# INFO    phase3.sources.vision  Vision 2/2/2  Vintage family photographs with daisies   — Early 20th century family photograph with period-appropriate
# INFO    phase3.sources.vision  Vision 1/3/3  A large gathering in Syria with people h  — Modern protest rally with Syrian nationalist flags, not earl
# INFO    phase3.sources.vision  Vision 2/2/2  Detailed close-up of the Saudi Arabian f  — Saudi flag with Islamic calligraphy fits Arab nationalism er
# INFO    phase3.sources  Shot 40: best=A large gathering in Syria with people holding fla (score 7)
# INFO    phase3.prebuild  Shot 42/archive: query='Balkan Wars 1912 1913 Ottoman army historical archive photog' duration=4.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Balkan Wars 1912 1913 Ottoman army historical archive photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Balkan Wars 1912 1913 Ottoman army historical archive photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Balkan Wars 1912 1913 Ottoman army historical archive photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Balkan Wars 1912 1913 Ottoman army historical archive photograph'
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — Ottoman-era military photograph matching the time period and
# INFO    phase3.sources.vision  Vision 1/3/2  Bronze relief depicting soldiers at a me  — Relief sculpture depicts military/historical subject matter
# INFO    phase3.sources.vision  Vision 1/3/2  A group of men in white uniforms partici  — Modern historical reenactment of Ottoman-era military unifor
# INFO    phase3.sources  Shot 42: best=Sepia-toned vintage photo of a man in uniform ridi (score 6)
# INFO    phase3.prebuild  Shot 44/broll: query='World War One Middle East desert campaign 1916 historical fo' duration=6.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'World War One Middle East desert campaign 1916 historical footage'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'World War One Middle East desert campaign 1916 historical footage'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'World War One Middle East desert campaign 1916 historical footage'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'World War One Middle East desert campaign 1916 historical footage'
# INFO    phase3.sources.vision  Vision 2/2/2  Aerial shot of historic ruins in Oman, s  — Aerial view of desert ruins fits WWI Middle East campaign er
# INFO    phase3.sources.vision  Vision 2/3/3  Stone arch aqueduct in Ma'an, Jordan und  — Roman/Ottoman aqueduct in arid Middle Eastern landscape matc
# INFO    phase3.sources.vision  Vision 2/2/2  Explore the historic ruins of ancient Ba  — Middle Eastern desert fortification with historical architec
# INFO    phase3.sources  Shot 44: best=Stone arch aqueduct in Ma'an, Jordan under clear b (score 8)
# INFO    phase3.prebuild  Shot 46/location: query='Libya North Africa Senussi movement desert 1915 World War On' duration=6.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Libya North Africa Senussi movement desert 1915 World War One'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Libya North Africa Senussi movement desert 1915 World War One'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Libya North Africa Senussi movement desert 1915 World War One'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Libya North Africa Senussi movement desert 1915 World War One'
# INFO    phase3.sources.vision  Vision 2/2/3  A man in traditional Moroccan attire kne  — Desert setting and North African atmosphere match the geogra
# INFO    phase3.sources.vision  Vision 2/2/2  Camels feed in the arid landscape of Al   — Desert landscape with camels matches North Africa/Libya sett
# INFO    phase3.sources.vision  Vision 2/3/3  Silhouette of a person in Drâa-Tafilalet  — Desert landscape with solitary figure evokes North African s
# INFO    phase3.sources  Shot 46: best=Silhouette of a person in Drâa-Tafilalet desert, M (score 8)
# INFO    phase3.prebuild  Shot 47/archive: query='Senussi movement North Africa Ottoman allied forces 1915 arc' duration=5.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Senussi movement North Africa Ottoman allied forces 1915 archive photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Senussi movement North Africa Ottoman allied forces 1915 archive photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Senussi movement North Africa Ottoman allied forces 1915 archive photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Senussi movement North Africa Ottoman allied forces 1915 archive photo'
# INFO    phase3.sources.vision  Vision 1/3/3  Black and white scene of protesters and   — Contemporary protest/conflict scene in North Africa with str
# INFO    phase3.sources.vision  Vision 2/2/2  Explore vintage family photo albums fill  — Period-appropriate archival photographs from early 20th cent
# INFO    phase3.sources.vision  Vision 1/3/2  Crowd at a public rally with Turkish fla  — Modern Turkish flag at mosque shows right region but wrong e
# INFO    phase3.sources  Shot 47: best=Black and white scene of protesters and police in  (score 7)
# INFO    phase3.prebuild  Shot 48/location: query='Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal milit' duration=5.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal military operations'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal military operations'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal military operations'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arabian Peninsula desert Hejaz 1916 Arab Revolt Faisal military operations'
# INFO    phase3.sources.vision  Vision 2/2/2  Overcast skies loom over the abandoned v  — Authentic desert architecture matching Hejaz region and earl
# INFO    phase3.sources.vision  Vision 2/3/3  A group of camels strolling through the   — Authentic desert scene with period-appropriate vehicle match
# INFO    phase3.sources.vision  Vision 1/3/2  Footprints trail across a pristine, whit  — Desert beach landscape is geographically plausible for Arabi
# INFO    phase3.sources  Shot 48: best=A group of camels strolling through the Dubai dese (score 8)
# INFO    phase3.prebuild  Shot 50/broll: query='Arab Revolt 1916 desert cavalry campaign historical document' duration=5.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab Revolt 1916 desert cavalry campaign historical documentary archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab Revolt 1916 desert cavalry campaign historical documentary archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab Revolt 1916 desert cavalry campaign historical documentary archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab Revolt 1916 desert cavalry campaign historical documentary archive'
# INFO    phase3.sources.vision  Vision 3/3/3  Traditional Moroccan horsemen in rich at  — Authentic desert cavalry scene with period costume, Moroccan
# INFO    phase3.sources.vision  Vision 2/3/3  Polish soldiers on horseback holding fla  — Period cavalry in formation with flags matches Arab Revolt e
# INFO    phase3.sources.vision  Vision 1/2/2  A close-up portrait of a man with a whit  — Contemporary portrait of man with horse in desert setting; e
# INFO    phase3.sources  Shot 50: best=Traditional Moroccan horsemen in rich attire again (score 9)
# INFO    phase3.prebuild  Shot 52/archive: query='Jafar al-Askari Faisal I Arab officers Iraq 1920 historical ' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Faisal I Arab officers Iraq 1920 historical photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Faisal I Arab officers Iraq 1920 historical photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Faisal I Arab officers Iraq 1920 historical photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Faisal I Arab officers Iraq 1920 historical photograph'
# INFO    phase3.sources.vision  Vision 2/2/2  A nostalgic display of vintage cameras i  — Historical museum display of period cameras and artifacts fr
# INFO    phase3.sources.vision  Vision 1/2/1  A man in traditional Yemeni dress poses   — Modern costume reenactment with period styling, not historic
# INFO    phase3.sources.vision  Vision 2/2/2  Explore the historic ruins of ancient Ba  — Historical Middle Eastern fortification matching 1920s Iraq
# INFO    phase3.sources  Shot 52: best=A nostalgic display of vintage cameras in a Kuwait (score 6)
# INFO    phase3.prebuild  Shot 54/object: query='old Arabic memoir book open pages historical document close-' duration=4.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'old Arabic memoir book open pages historical document close-up'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'old Arabic memoir book open pages historical document close-up'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'old Arabic memoir book open pages historical document close-up'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'old Arabic memoir book open pages historical document close-up'
# INFO    phase3.sources.vision  Vision 3/2/2  A close-up of an antique open book with   — Authentic historical Arabic manuscript with period-appropria
# INFO    phase3.sources.vision  Vision 3/3/3  Black and white photo of an open Arabic   — Authentic close-up of open Arabic manuscript with period bin
# INFO    phase3.sources.vision  Vision 3/2/2  Close-up view of Arabic script on a book  — Authentic Arabic historical document with shallow depth-of-f
# INFO    phase3.sources  Shot 54: best=Black and white photo of an open Arabic book with  (score 9)
# INFO    phase3.prebuild  Shot 56/broll: query='historical crossroads old and new world change transformatio' duration=5.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'historical crossroads old and new world change transformation documentary'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical crossroads old and new world change transformation documentary'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'historical crossroads old and new world change transformation documentary'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical crossroads old and new world change transformation documentary'
# INFO    phase3.sources.vision  Vision 2/3/3  A Holy Bible rests on an antique style w  — Antique world map with Holy Bible symbolizes historical cros
# INFO    phase3.sources.vision  Vision 1/3/3  Drone shot of a forest road intersection  — Aerial road through forest metaphorically suggests transform
# INFO    phase3.sources.vision  Vision 2/3/3  A classic pocket watch rests on an old w  — Vintage pocket watch on antique map perfectly evokes histori
# INFO    phase3.sources  Shot 56: best=A Holy Bible rests on an antique style world map w (score 8)
# INFO    phase3.prebuild  Shot 58/portrait: query='Najda Fathi Safwat Iraqi historian scholar portrait' duration=5.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.vision  Vision 0/2/2  Close-up of a middle-eastern woman in a   — Portrait shows a woman in traditional headscarf with contemp
# INFO    phase3.sources.vision  Vision 1/2/2  Young graduate woman smiling in cap and   — Modern graduation portrait unrelated to Jafar al-Askari (ear
# INFO    phase3.sources.vision  Vision 1/3/3  Black and white photo of a man reading i  — Well-composed archival-style portrait of a scholar with book
# INFO    phase3.sources  Shot 58: best=Black and white photo of a man reading in a vintag (score 7)
# INFO    phase3.prebuild  Shot 60/object: query='Jafar al-Askari memoirs book cover Arabic edition close-up' duration=6.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition close-up'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition close-up'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition close-up'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari memoirs book cover Arabic edition close-up'
# INFO    phase3.sources.vision  Vision 3/3/2  Beautiful Quran with intricate Arabic ca  — Exact match: Islamic scholarly book with Arabic calligraphy
# INFO    phase3.sources.vision  Vision 3/3/3  Close-up of the Quran on a wooden stand,  — Authentic Islamic manuscript presentation with ornate Qurani
# INFO    phase3.sources.vision  Vision 3/3/3  Close-up image of the Quran with black p  — Authentic close-up of Islamic book with Arabic calligraphy,
# INFO    phase3.sources  Shot 60: best=Close-up of the Quran on a wooden stand, symbolizi (score 9)
# INFO    phase3.prebuild  Shot 61/broll: query='historical maps documents letters manuscripts Arabic archive' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'historical maps documents letters manuscripts Arabic archive Middle East'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical maps documents letters manuscripts Arabic archive Middle East'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'historical maps documents letters manuscripts Arabic archive Middle East'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical maps documents letters manuscripts Arabic archive Middle East'
# INFO    phase3.sources.vision  Vision 3/3/3  Detailed view of an ancient illuminated   — Authentic antique Arabic manuscripts with ornate bindings an
# INFO    phase3.sources.vision  Vision 3/3/3  Detailed image of ancient Arabic calligr  — Authentic historical Arabic manuscript with ornate Islamic c
# INFO    phase3.sources.vision  Vision 3/3/3  Close-up of an ancient manuscript featur  — Authentic historical Arabic manuscript with ornate calligrap
# INFO    phase3.sources  Shot 61: best=Detailed view of an ancient illuminated manuscript (score 9)
# INFO    phase3.prebuild  Shot 64/portrait: query='Jafar al-Askari Iraqi prime minister politician historical p' duration=6.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi prime minister politician historical portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi prime minister politician historical portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi prime minister politician historical portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi prime minister politician historical portrait'
# INFO    phase3.sources.vision  Vision 1/3/2  Man in a tuxedo smiling indoors in a lux  — Modern formal portrait in period-appropriate setting, but su
# INFO    phase3.sources.vision  Vision 1/2/2  A businessman in formal attire exits an   — Depicts a formally dressed man descending aircraft stairs in
# INFO    phase3.sources.vision  Vision 1/3/3  A diverse group of people enjoying a cin  — Contemporary cinema scene with Middle Eastern subjects in fo
# INFO    phase3.sources  Shot 64: best=A diverse group of people enjoying a cinematic exp (score 7)
# INFO    phase3.prebuild  Shot 66/object: query='Arabic book memoir historical elegant cover typography close' duration=6.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arabic book memoir historical elegant cover typography close-up'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arabic book memoir historical elegant cover typography close-up'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arabic book memoir historical elegant cover typography close-up'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arabic book memoir historical elegant cover typography close-up'
# INFO    phase3.sources.vision  Vision 3/2/2  Close-up view of Arabic script on a book  — Authentic Arabic historical text with visible typography and
# INFO    phase3.sources.vision  Vision 3/2/2  Detailed close-up of Arabic text on an o  — Authentic Arabic manuscript page with clear historical typog
# INFO    phase3.sources.vision  Vision 3/3/3  Black and white photo of an open Arabic   — Authentic Arabic manuscript with elegant typography, sharp m
# INFO    phase3.sources  Shot 66: best=Black and white photo of an open Arabic book with  (score 9)
# INFO    phase3.sources.decisions  Decisions written → /content/output/review/decisions.json
#
# ────────────────────────────────────────────────────────────────
# Review dossier ready: /content/output/review
# Image shots processed:  36
#   with a chosen winner: 36
#   with no candidates:   0
# Winner source breakdown:
#   pexels           36
# Pinned portrait:        overrides/character.jpg
#   affects 6 portrait shot(s) at render time
# Book cover:             overrides/book_cover.jpg
#   fit mode:             contain
#   align:                left
#   affects 2 title-card shot(s) at render time
#
# Next:
#   1. Open /content/output/review/ and review each shot folder.
#   2. Edit /content/output/review/decisions.json to swap candidates,
#      drop overrides into /content/output/review/overrides/,
#      or set 'pinned_portrait'.
#   3. Render:
#      python render_plan.py --plan output/al_askari_plan_v2.json \
#          --review-dir /content/output/review \
#          --audio <audio> --output <output.mp4>
# ────────────────────────────────────────────────────────────────
# 🧩 Prebuild completed!

# %%
import os
import zipfile

output_dir = 'output/review'
zip_filename = 'review.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            file_path = os.path.join(root, file)
            # Add file to zip, preserving directory structure relative to 'output_dir'
            # Skip .mp3 files if any exist (though unlikely in review folder)
            if not file_path.endswith('.mp3'):
                zipf.write(file_path, os.path.relpath(file_path, output_dir))
                files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing: ")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print("  (No files found to zip in the 'output/review' directory.)")
# Out:
# 🤐 Successfully created 'review.zip' containing:
#   - output/review/decisions.json
#   - output/review/README.txt
#   - output/review/shot_40_broll/pexels_b.jpg
#   - output/review/shot_40_broll/candidates.json
#   - output/review/shot_40_broll/pexels_c.jpg
#   - output/review/shot_40_broll/context.txt
#   - output/review/shot_40_broll/pexels_a.jpg
#   - output/review/shot_09_broll/pexels_b.jpg
#   - output/review/shot_09_broll/candidates.json
#   - output/review/shot_09_broll/pexels_c.jpg
#   - output/review/shot_09_broll/context.txt
#   - output/review/shot_09_broll/pexels_a.jpg
#   - output/review/shot_48_location/pexels_b.jpg
#   - output/review/shot_48_location/candidates.json
#   - output/review/shot_48_location/pexels_c.jpg
#   - output/review/shot_48_location/context.txt
#   - output/review/shot_48_location/pexels_a.jpg
#   - output/review/shot_50_broll/pexels_b.jpg
#   - output/review/shot_50_broll/candidates.json
#   - output/review/shot_50_broll/pexels_c.jpg
#   - output/review/shot_50_broll/context.txt
#   - output/review/shot_50_broll/pexels_a.jpg
#   - output/review/shot_46_location/pexels_b.jpg
#   - output/review/shot_46_location/candidates.json
#   - output/review/shot_46_location/pexels_c.jpg
#   - output/review/shot_46_location/context.txt
#   - output/review/shot_46_location/pexels_a.jpg
#   - output/review/shot_38_portrait/pexels_b.jpg
#   - output/review/shot_38_portrait/candidates.json
#   - output/review/shot_38_portrait/pexels_c.jpg
#   - output/review/shot_38_portrait/context.txt
#   - output/review/shot_38_portrait/pexels_a.jpg
#   - output/review/shot_26_broll/pexels_b.jpg
#   - output/review/shot_26_broll/candidates.json
#   - output/review/shot_26_broll/pexels_c.jpg
#   - output/review/shot_26_broll/context.txt
#   - output/review/shot_26_broll/pexels_a.jpg
#   - output/review/shot_17_broll/pexels_b.png
#   - output/review/shot_17_broll/candidates.json
#   - output/review/shot_17_broll/pexels_c.jpg
#   - output/review/shot_17_broll/context.txt
#   - output/review/shot_17_broll/pexels_a.jpg
#   - output/review/shot_54_object/pexels_b.jpg
#   - output/review/shot_54_object/candidates.json
#   - output/review/shot_54_object/pexels_c.jpg
#   - output/review/shot_54_object/context.txt
#   - output/review/shot_54_object/pexels_a.jpg
#   - output/review/shot_61_broll/pexels_b.jpg
#   - output/review/shot_61_broll/candidates.json
#   - output/review/shot_61_broll/pexels_c.jpg
#   - output/review/shot_61_broll/context.txt
#   - output/review/shot_61_broll/pexels_a.jpg
#   - output/review/shot_42_archive/pexels_b.jpg
#   - output/review/shot_42_archive/candidates.json
#   - output/review/shot_42_archive/pexels_c.jpg
#   - output/review/shot_42_archive/context.txt
#   - output/review/shot_42_archive/pexels_a.jpg
#   - output/review/shot_04_archive/pexels_b.jpg
#   - output/review/shot_04_archive/candidates.json
#   - output/review/shot_04_archive/pexels_c.jpg
#   - output/review/shot_04_archive/context.txt
#   - output/review/shot_04_archive/pexels_a.jpg
#   - output/review/shot_64_portrait/pexels_b.jpg
#   - output/review/shot_64_portrait/candidates.json
#   - output/review/shot_64_portrait/pexels_c.jpg
#   - output/review/shot_64_portrait/context.txt
#   - output/review/shot_64_portrait/pexels_a.jpg
#   - output/review/shot_28_location/pexels_b.jpg
#   - output/review/shot_28_location/candidates.json
#   - output/review/shot_28_location/pexels_c.jpg
#   - output/review/shot_28_location/context.txt
#   - output/review/shot_28_location/pexels_a.jpg
#   - output/review/shot_05_portrait/pexels_b.jpg
#   - output/review/shot_05_portrait/candidates.json
#   - output/review/shot_05_portrait/pexels_c.jpg
#   - output/review/shot_05_portrait/context.txt
#   - output/review/shot_05_portrait/pexels_a.jpg
#   - output/review/shot_15_location/pexels_b.jpg
#   - output/review/shot_15_location/candidates.json
#   - output/review/shot_15_location/pexels_c.jpg
#   - output/review/shot_15_location/context.txt
#   - output/review/shot_15_location/pexels_a.jpg
#   - output/review/shot_16_archive/pexels_b.jpg
#   - output/review/shot_16_archive/candidates.json
#   - output/review/shot_16_archive/pexels_c.jpg
#   - output/review/shot_16_archive/context.txt
#   - output/review/shot_16_archive/pexels_a.jpg
#   - output/review/shot_32_portrait/pexels_b.jpg
#   - output/review/shot_32_portrait/candidates.json
#   - output/review/shot_32_portrait/pexels_c.jpg
#   - output/review/shot_32_portrait/context.txt
#   - output/review/shot_32_portrait/pexels_a.jpg
#   - output/review/overrides/character.jpg
#   - output/review/overrides/book_cover.jpg
#   - output/review/shot_24_archive/pexels_b.jpg
#   - output/review/shot_24_archive/candidates.json
#   - output/review/shot_24_archive/pexels_c.jpg
#   - output/review/shot_24_archive/context.txt
#   - output/review/shot_24_archive/pexels_a.jpg
#   - output/review/shot_19_portrait/pexels_b.jpg
#   - output/review/shot_19_portrait/candidates.json
#   - output/review/shot_19_portrait/pexels_c.jpg
#   - output/review/shot_19_portrait/context.txt
#   - output/review/shot_19_portrait/pexels_a.jpg
#   - output/review/shot_31_archive/pexels_b.jpg
#   - output/review/shot_31_archive/candidates.json
#   - output/review/shot_31_archive/pexels_c.jpg
#   - output/review/shot_31_archive/context.txt
#   - output/review/shot_31_archive/pexels_a.jpg
#   - output/review/shot_13_archive/pexels_b.jpg
#   - output/review/shot_13_archive/candidates.json
#   - output/review/shot_13_archive/pexels_c.jpg
#   - output/review/shot_13_archive/context.txt
#   - output/review/shot_13_archive/pexels_a.jpg
#   - output/review/shot_47_archive/pexels_b.jpg
#   - output/review/shot_47_archive/candidates.json
#   - output/review/shot_47_archive/pexels_c.jpg
#   - output/review/shot_47_archive/context.txt
#   - output/review/shot_47_archive/pexels_a.jpg
#   - output/review/shot_22_broll/pexels_b.jpg
#   - output/review/shot_22_broll/candidates.json
#   - output/review/shot_22_broll/pexels_c.jpg
#   - output/review/shot_22_broll/context.txt
#   - output/review/shot_22_broll/pexels_a.jpg
#   - output/review/shot_56_broll/pexels_b.jpg
#   - output/review/shot_56_broll/candidates.json
#   - output/review/shot_56_broll/pexels_c.jpg
#   - output/review/shot_56_broll/context.txt
#   - output/review/shot_56_broll/pexels_a.jpg
#   - output/review/shot_44_broll/pexels_b.jpg
#   - output/review/shot_44_broll/candidates.json
#   - output/review/shot_44_broll/pexels_c.jpg
#   - output/review/shot_44_broll/context.txt
#   - output/review/shot_44_broll/pexels_a.jpg
#   - output/review/shot_29_archive/pexels_b.jpg
#   - output/review/shot_29_archive/candidates.json
#   - output/review/shot_29_archive/pexels_c.jpg
#   - output/review/shot_29_archive/context.txt
#   - output/review/shot_29_archive/pexels_a.jpg
#   - output/review/shot_07_broll/pexels_b.jpg
#   - output/review/shot_07_broll/candidates.json
#   - output/review/shot_07_broll/pexels_c.jpg
#   - output/review/shot_07_broll/context.txt
#   - output/review/shot_07_broll/pexels_a.jpg
#   - output/review/shot_12_location/pexels_b.jpg
#   - output/review/shot_12_location/candidates.json
#   - output/review/shot_12_location/pexels_c.jpg
#   - output/review/shot_12_location/context.txt
#   - output/review/shot_12_location/pexels_a.jpg
#   - output/review/shot_52_archive/pexels_b.jpg
#   - output/review/shot_52_archive/candidates.json
#   - output/review/shot_52_archive/pexels_c.jpg
#   - output/review/shot_52_archive/context.txt
#   - output/review/shot_52_archive/pexels_a.jpg
#   - output/review/shot_58_portrait/pexels_b.jpg
#   - output/review/shot_58_portrait/candidates.json
#   - output/review/shot_58_portrait/pexels_c.jpg
#   - output/review/shot_58_portrait/context.txt
#   - output/review/shot_58_portrait/pexels_a.jpg
#   - output/review/shot_66_object/pexels_b.jpg
#   - output/review/shot_66_object/candidates.json
#   - output/review/shot_66_object/pexels_c.jpg
#   - output/review/shot_66_object/context.txt
#   - output/review/shot_66_object/pexels_a.jpg
#   - output/review/shot_36_broll/pexels_b.jpg
#   - output/review/shot_36_broll/candidates.json
#   - output/review/shot_36_broll/pexels_c.jpg
#   - output/review/shot_36_broll/context.txt
#   - output/review/shot_36_broll/pexels_a.jpg
#   - output/review/shot_20_broll/pexels_b.jpg
#   - output/review/shot_20_broll/candidates.json
#   - output/review/shot_20_broll/pexels_c.jpg
#   - output/review/shot_20_broll/context.txt
#   - output/review/shot_20_broll/pexels_a.jpg
#   - output/review/shot_60_object/pexels_b.jpg
#   - output/review/shot_60_object/candidates.json
#   - output/review/shot_60_object/pexels_c.jpg
#   - output/review/shot_60_object/context.txt
#   - output/review/shot_60_object/pexels_a.jpg
#   - output/review/shot_34_broll/pexels_b.jpg
#   - output/review/shot_34_broll/candidates.json
#   - output/review/shot_34_broll/pexels_c.jpg
#   - output/review/shot_34_broll/context.txt
#   - output/review/shot_34_broll/pexels_a.jpg

# %%
# Standalone test runner
# !python verify_user_marked.py
# Out:
# INFO    verify  ── regex tests ──
# INFO    verify  regex: 13 cases, 0 failed
# INFO    verify  ── resolution tests ──
# INFO    phase3.sources.decisions  Shot 5: user-marked file hit my_jafar.jpg
# INFO    phase3.sources.decisions  Shot 16: pinned-portrait hit character.jpg
# INFO    phase3.sources.decisions  Shot 28: chosen-file hit pexels_b.jpg
# INFO    phase3.sources.decisions  Shot 44: user-marked file hit User_Map.PNG
# INFO    verify  resolution: 4 scenarios, 0 failed
# INFO    verify  ✓ All checks passed

# %%
# !python verify_title_card.py --book-cover my_book.jpg
# Out:
# INFO    verify4  ── typography ──
# INFO    phase3.typography_common  Amiri fonts loaded via repo fonts/ (next to phase3): /content/fonts
# INFO    verify4  ✓ typography fields present
# Traceback (most recent call last):
#   File "/content/verify_title_card.py", line 150, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/verify_title_card.py", line 142, in main
#     log.info("── typography ──"); check_typography()
#                                   ^^^^^^^^^^^^^^^^^^
#   File "/content/verify_title_card.py", line 43, in check_typography
#     assert t.SIZES["title_main"] == 0.110, f"title_main is {t.SIZES['title_main']}, expected 0.110"
#            ^^^^^^^
# AttributeError: module 'phase3.typography' has no attribute 'SIZES'

# %%
# !python diagnose_issue4.py --review-dir output/review/   # is everything in place?
# Out:
# ── typography.py ──
# Amiri fonts loaded via repo fonts/ (next to phase3): /content/fonts
#   loaded from: /content/phase3/typography.py
#   ✓ GOLD_AGED constant present: (200, 162, 74)
#   ✓ TypographySpec.cover_image present
#   ✓ TypographySpec.accent_color present
# Traceback (most recent call last):
#   File "/content/diagnose_issue4.py", line 309, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/diagnose_issue4.py", line 285, in main
#     typo_ok    = check_typography_patched()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/diagnose_issue4.py", line 59, in check_typography_patched
#     title_main = t.SIZES.get("title_main")
#                  ^^^^^^^
# AttributeError: module 'phase3.typography' has no attribute 'SIZES'

# %%
import os

# Step 3: user reviews output/review/ — opens decisions.json, swaps a
# few `chosen_url` values, drops shot_03.jpg / shot_38.jpg overrides.

# Step 4: render — render_plan.py reads the decisions file
# The --review-dir argument consumes user's choices
# !python render_plan.py \
--plan         output/al_askari_plan_v2.json \
--audio        output/al_askari_audio.mp3 \
--review-dir   output/review/ \
--book-cover-fit contain \
--output       output/final_cut_C.mp4 \
--no-captions \
--typography-family C \
> output/render.log 2>&1 &

print("Rendering begins ...")
# Out:
# Rendering begins ...

# %%
# Monitor rendering progress
import time
from IPython.display import clear_output

log_path = "output/render.log"

print("Monitoring rendering progress...")
while True:
    try:
        # Read the log file contents
        try:
            with open(log_path, "r") as f:
                log_content = f.read()
        except FileNotFoundError:
            log_content = ""

        # Clear cell output and show the last 20 lines
        clear_output(wait=True)
        lines = log_content.splitlines()
        print("\n".join(lines[-20:]))

        # Check if the script's success signature is in the log
        if "Done in" in log_content or "Rendered video →" in log_content:
            print("\n✅ Rendering process completed successfully! Stopped monitoring.")
            break

        time.sleep(5)

    except KeyboardInterrupt:
        print("\n⚠️ Monitoring stopped manually. The script may still be running.")
        break
# Out:
#   [█████████████████████░░░░░░░░░]  71%  shot 64/67: portrait                                                  INFO  phase3.render  [render 73%] shot 65/67: typography
#
#   [█████████████████████░░░░░░░░░]  72%  shot 65/67: typography                                                INFO  phase3.sources.decisions  Shot 66: chosen-file hit pexels_c.jpg
# INFO  phase3.sources  Shot 66: review-dossier hit pexels_c.jpg
# INFO  phase3.render  Shot 66: using fetched image from user_upload
# INFO  phase3.render  [render 74%] shot 66/67: object
#
#   [██████████████████████░░░░░░░░]  73%  shot 66/67: object                                                    INFO  phase3.render  [render 75%] shot 67/67: title_card
#
#   [██████████████████████░░░░░░░░]  75%  shot 67/67: title_card                                                INFO  phase3.render  [render 80%] concat all shots
#
#   [████████████████████████░░░░░░]  80%  concat all shots                                                      INFO  phase3.render  [render 92%] mux audio and captions
#
#   [███████████████████████████░░░]  92%  mux audio and captions                                                INFO  phase3.render  [render 100%] done
#
#   [██████████████████████████████] 100%  done
# INFO  phase3.render  Rendered video → output/final_cut_C.mp4
#
# Done in 1190s  —  output/final_cut_C.mp4  (41.4 MB)
#
# ✅ Rendering process completed successfully! Stopped monitoring.

# %%
# !python diagnose_captions.py --plan output/al_askari_plan_v2.json   # inspect actual ASS events
# Out:
# render.py loaded from : /content/phase3/render.py
# GAP in source         : 0.15
# MIN_VISIBLE in source : 0.6
#
# plan                  : output/al_askari_plan_v2.json  (67 shots)
# events parsed         : 36
#
#   #    start      end   span  gap_from_prev  lines  text (first 50 chars)
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   1   13.760   18.200  4.440                     2  بل شهادةٌ حيّةٌ من ⏎ قلب أحداثٍ غيّرت وجهَ المنطقة
#   2   18.500   23.290  4.790        +0.300s      1  العربية إنها مذكراتُ جعفر العسكري، الضابط العراقي
#   3   29.030   33.820  4.790        +5.740s      2  العربية، وترك لنا سجلاً دقيقاً ⏎ عن حقبة لم يعرفها …
#   4   40.280   44.950  4.670        +6.460s      2  يقف بين ولاء الدولة ⏎ التي أعطته الكتائب والحلم بوط…
#   5   55.430   59.390  3.960       +10.480s      1  يبدأ جعفر العسكري رحلته من الموصل سنة ١٩٠٤،
#   6   59.690   63.540  3.850        +0.300s      1  حين غادر وطنه الأول إلى الاستانة لينضم إلى
#   7   69.400   74.900  5.500        +5.860s      2  بل كانت عبوراً من عالم ⏎ تقليدي إلى آفاق حديثة مليئ…
#   8   75.200   80.470  5.270        +0.300s      1  الألمانية والأوروبية والتفكير المتنوّر الذي بدأ ين…
#   9   80.770   85.790  5.020        +0.300s      2  بين الضباط الشباب في ⏎ الدولة العثمانية في قاعات ال…
#  10   91.890   97.040  5.150        +6.100s      2  جميعهم يحملون حلماً واحداً ⏎ إصلاح الجيش والدولة من…
#  11   97.340  103.080  5.740        +0.300s      1  الحداثة والمعرفة العسكرية الأوروبية كانت الدولة ال…
#  12  109.410  115.030  5.620        +6.330s      2  والإدارة لكن جعفر وزملاءه ⏎ اكتشفوا بسرعة أن الإصلا…
#  13  121.720  126.870  5.150        +6.690s      1  العقول والمؤسسات من القيود الاستبدادية هذه المرحلة…
#  14  133.800  141.190  7.390        +6.930s      2  أن التعليم والجيش الحديث يمكنهما أن ⏎ يكونا أداة ال…
#  15  146.350  150.660  4.310        +5.160s      1  مع اقتراب جعفر من أوساط السلطة والعمل السياسي،
#
# Gaps (first 14): min=0.300s  avg=4.375s  max=10.480s
# Wrapped events: 8/15 have an explicit \N break
#
# ✓ Gaps ~0.30s AND captions wrapped cleanly — v3.2 PATCH IS LIVE.

# %%
# Zip output files for exporting
import os
import zipfile

output_dir = 'output'
zip_filename = 'output_files.zip'

# Get all files in the output directory
files_to_zip = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]

# Filter out the .mp3 file
filtered_files = [f for f in files_to_zip if not f.endswith('.mp3')]

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file_path in filtered_files:
        # Add file to zip, preserving directory structure relative to 'output_dir'
        zipf.write(file_path, os.path.relpath(file_path, output_dir))

print(f"🤐 Successfully created '{zip_filename}' containing: ")
for f in filtered_files:
    print(f"  - {f}")
# Out:
# 🤐 Successfully created 'output_files.zip' containing:
#   - output/final_cut_C.mp4
#   - output/al_askari_plan_v2.json
#   - output/render.log
#   - output/planner_raw_response.txt
#   - output/word_timings.json

# %%
# Save zipped file to Drive
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# Define the destination directory and file path
dest_dir = '/content/drive/MyDrive/_Phase3'
dest_file_path = os.path.join(dest_dir, 'output_files.zip')

# Create the destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)
print(f"Destination directory '{dest_dir}' ensured to exist.")

# --- Test write access to the directory ---
test_file = os.path.join(dest_dir, 'test_write.txt')
try:
    with open(test_file, 'w') as f:
        f.write('This is a test file.\n')
    print(f"✅ Successfully wrote test file to '{test_file}'.")
    os.remove(test_file) # Clean up the test file
    print(f"Test file '{test_file}' removed.")
except Exception as e:
    print(f"Error writing test file to '{test_file}': {e}")
    print("⚠️ It seems there might be a permissions or access issue with Google Drive.")
    # Exit or raise an error if write access fails
    raise
# ----------------------------------------

shutil.copy('/content/output_files.zip', dest_file_path)
print(f"📽️ rough_cut.mp4 saved to Google Drive at '{dest_file_path}'.")
# Out:
# Mounted at /content/drive
# Destination directory '/content/drive/MyDrive/_Phase3' ensured to exist.
# ✅ Successfully wrote test file to '/content/drive/MyDrive/_Phase3/test_write.txt'.
# Test file '/content/drive/MyDrive/_Phase3/test_write.txt' removed.
# 📽️ rough_cut.mp4 saved to Google Drive at '/content/drive/MyDrive/_Phase3/output_files.zip'.
