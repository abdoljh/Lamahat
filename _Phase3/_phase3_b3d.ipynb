# %%
# Script source: GitHub repo
import os
import shutil

github_url_path = "https://github.com/abdoljh/Lamahat/tree/main/_Phase3"

# Extract the base GitHub repository URL and the subfolder path
def parse_github_path(url):
    parts = url.split('/tree/main/')
    repo_url = parts[0]
    subfolder_path = parts[1] if len(parts) > 1 else ''
    # Add .git for cloning
    repo_url_for_clone = repo_url + '.git'
    return repo_url_for_clone, subfolder_path

repo_url_for_clone, subfolder_path_in_repo = parse_github_path(github_url_path)

repo_name = repo_url_for_clone.split('/')[-1].replace('.git', '')
temp_clone_dir = os.path.join('/tmp', repo_name)
dest_dir_colab = '/content'

print(f"Cloning repository: {repo_url_for_clone}")
print(f"Target subfolder in repo: {subfolder_path_in_repo}")

# Clean up any previous clone to avoid issues
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Removed existing temporary directory: {temp_clone_dir}")

# Clone the repository
clone_command = f"git clone {repo_url_for_clone} {temp_clone_dir}"
print(f"Executing: {clone_command}")
os.system(clone_command)

# Check if cloning was successful
if not os.path.exists(temp_clone_dir):
    print(f"Error: Failed to clone repository {repo_url_for_clone}")
else:
    source_dir_to_copy = os.path.join(temp_clone_dir, subfolder_path_in_repo)
    if not os.path.exists(source_dir_to_copy):
        print(f"Error: Subfolder '{subfolder_path_in_repo}' not found in cloned repository at '{source_dir_to_copy}'")
    else:
        print(f"Source directory to copy: {source_dir_to_copy}")
        print(f"Copying contents of '{source_dir_to_copy}' directly into '{dest_dir_colab}'.")

        # Define directories to skip
        dirs_to_skip = ['artifacts', 'review']

        try:
            for item in os.listdir(source_dir_to_copy):
                if item in dirs_to_skip:
                    print(f"Skipping directory '{item}' as requested.")
                    continue

                source_item_path = os.path.join(source_dir_to_copy, item)
                dest_item_path = os.path.join(dest_dir_colab, item)

                # If item already exists in destination, remove it to avoid errors
                if os.path.exists(dest_item_path):
                    if os.path.isdir(dest_item_path):
                        shutil.rmtree(dest_item_path)
                        print(f"Removed existing directory '{dest_item_path}'.")
                    else:
                        os.remove(dest_item_path)
                        print(f"Removed existing file '{dest_item_path}'.")

                if os.path.isdir(source_item_path):
                    shutil.copytree(source_item_path, dest_item_path)
                else:
                    shutil.copy2(source_item_path, dest_item_path)
                print(f"Copied '{source_item_path}' to '{dest_item_path}'.")
            print(f"Successfully copied contents of '{source_dir_to_copy}' to '{dest_dir_colab}'.")

        except Exception as e:
            print(f"An error occurred during directory contents copy: {e}")

# Clean up the cloned repository
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Cleaned up temporary clone directory: {temp_clone_dir}")

print("😺 GitHub repo loaded!")
# Out:
# Cloning repository: https://github.com/abdoljh/Lamahat.git
# Target subfolder in repo: _Phase3
# Executing: git clone https://github.com/abdoljh/Lamahat.git /tmp/Lamahat
# Source directory to copy: /tmp/Lamahat/_Phase3
# Copying contents of '/tmp/Lamahat/_Phase3' directly into '/content'.
# Copied '/tmp/Lamahat/_Phase3/INSTALL.md' to '/content/INSTALL.md'.
# Copied '/tmp/Lamahat/_Phase3/verify_title_card.py' to '/content/verify_title_card.py'.
# Copied '/tmp/Lamahat/_Phase3/my_book_cover.jpg' to '/content/my_book_cover.jpg'.
# Copied '/tmp/Lamahat/_Phase3/Phase3.md' to '/content/Phase3.md'.
# Copied '/tmp/Lamahat/_Phase3/my_book_cover_1.jpg' to '/content/my_book_cover_1.jpg'.
# Copied '/tmp/Lamahat/_Phase3/trim_book_cover.py' to '/content/trim_book_cover.py'.
# Copied '/tmp/Lamahat/_Phase3/diagnose_captions.py' to '/content/diagnose_captions.py'.
# Copied '/tmp/Lamahat/_Phase3/make_test_png.py' to '/content/make_test_png.py'.
# Copied '/tmp/Lamahat/_Phase3/fonts' to '/content/fonts'.
# Copied '/tmp/Lamahat/_Phase3/render_plan.py' to '/content/render_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/output' to '/content/output'.
# Copied '/tmp/Lamahat/_Phase3/samples' to '/content/samples'.
# Skipping directory 'review' as requested.
# Copied '/tmp/Lamahat/_Phase3/phase3_run.py' to '/content/phase3_run.py'.
# Copied '/tmp/Lamahat/_Phase3/verify_user_marked.py' to '/content/verify_user_marked.py'.
# Copied '/tmp/Lamahat/_Phase3/prebuild_assets.py' to '/content/prebuild_assets.py'.
# Copied '/tmp/Lamahat/_Phase3/audit_plan.py' to '/content/audit_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/diagnose_issue4.py' to '/content/diagnose_issue4.py'.
# Copied '/tmp/Lamahat/_Phase3/my_jafar.jpg' to '/content/my_jafar.jpg'.
# Copied '/tmp/Lamahat/_Phase3/sandbox_test.py' to '/content/sandbox_test.py'.
# Copied '/tmp/Lamahat/_Phase3/phase3' to '/content/phase3'.
# Skipping directory 'artifacts' as requested.
# Copied '/tmp/Lamahat/_Phase3/verify_font_discovery.py' to '/content/verify_font_discovery.py'.
# Copied '/tmp/Lamahat/_Phase3/CLAUDE.md' to '/content/CLAUDE.md'.
# Copied '/tmp/Lamahat/_Phase3/_phase3_b3c.ipynb' to '/content/_phase3_b3c.ipynb'.
# Copied '/tmp/Lamahat/_Phase3/temp' to '/content/temp'.
# Copied '/tmp/Lamahat/_Phase3/my_book.jpg' to '/content/my_book.jpg'.
# Successfully copied contents of '/tmp/Lamahat/_Phase3' to '/content'.
# Cleaned up temporary clone directory: /tmp/Lamahat
# 😺 GitHub repo loaded!

# %%
from pathlib import Path
from phase3.typography_common import TypographySpec
from phase3.typography import render
import os

# Ensure the target directory exists
output_dir = '/content/temp'
os.makedirs(output_dir, exist_ok=True)

rendered_files_expected = []
for fam in ("A", "B", "C"):
    for tpl in ("title_card", "section_mark", "pull_quote", "name_reveal", "date_stamp"):
        spec = TypographySpec(
            template=tpl, family=fam,
            text="مذكرات جعفر العسكري",
            subtitle="١٨٨٥ - ١٩٣٦",
            width=1920, height=1080,
        )
        file_path = Path(f"{output_dir}/typo_{fam}_{tpl}.png")
        render(spec, file_path)
        rendered_files_expected.append(file_path)

print("💨 Typography examples rendering process completed.")

# Verification step
print(f"\nVerifying files in '{output_dir}':")
found_files_actual = []
for f_expected in rendered_files_expected:
    if f_expected.exists():
        found_files_actual.append(f_expected.name)
        print(f"  ✅ Found: {f_expected.name}")
    else:
        print(f"  ❌ NOT found: {f_expected.name}")

if not found_files_actual:
    print(f"No rendered image files were found in '{output_dir}'.")
    print("This suggests an issue with the `render` function from `phase3.typography` not creating the files as expected, or writing them to a different location.")
else:
    print(f"\nSuccessfully found {len(found_files_actual)} rendered files.")
# Out:
# Typography examples rendering process completed.
#
# Verifying files in 'content/temp':
#   ✅ Found: typo_A_title_card.png
#   ✅ Found: typo_A_section_mark.png
#   ✅ Found: typo_A_pull_quote.png
#   ✅ Found: typo_A_name_reveal.png
#   ✅ Found: typo_A_date_stamp.png
#   ✅ Found: typo_B_title_card.png
#   ✅ Found: typo_B_section_mark.png
#   ✅ Found: typo_B_pull_quote.png
#   ✅ Found: typo_B_name_reveal.png
#   ✅ Found: typo_B_date_stamp.png
#
# Successfully found 10 rendered files.

# %%
import os
import zipfile

image_dir = '/content/temp'
zip_filename = 'typography_images.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    if os.path.exists(image_dir):
        for root, dirs, files in os.walk(image_dir):
            for file in files:
                if file.endswith('.png'): # Only zip PNG images
                    file_path = os.path.join(root, file)
                    # Add file to zip, preserving directory structure relative to 'image_dir'
                    zipf.write(file_path, os.path.relpath(file_path, image_dir))
                    files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing:")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print(f"  (No .png files found in '{image_dir}' to zip.)")
# Out:
# 🤐 Successfully created 'typography_images.zip' containing:
#   - content/temp/typo_B_title_card.png
#   - content/temp/typo_A_name_reveal.png
#   - content/temp/typo_B_name_reveal.png
#   - content/temp/typo_A_date_stamp.png
#   - content/temp/typo_A_title_card.png
#   - content/temp/typo_A_section_mark.png
#   - content/temp/typo_B_section_mark.png
#   - content/temp/typo_A_pull_quote.png
#   - content/temp/typo_B_date_stamp.png
#   - content/temp/typo_B_pull_quote.png

# %%
# Verify font discovery (OPTIONAL)
# !python verify_font_discovery.py

# %%
# Check font paths (OPTIONAL)
# !python -c "from phase3.typography import FONT_PATHS; print(FONT_PATHS)"
# print("✅ Pre-testingvthe discovery of Amiri fonts completed!")

# %%
# !pip install anthropic
print("✴️ Anthropic installed!")
# Out:
# Collecting anthropic
#   Downloading anthropic-0.103.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.103.1-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.6/832.6 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.103.1
# ✴️ Anthropic installed!

# %%
# !pip install whisperx openai-whisper
# print("✅ whisperx and openai-whisper installed!")

# %%
# !pip install arabic-reshaper python-bidi
# print("✅ Arabic_reshaper and python-bidi installed!")

# %%
print("Retrieving the Anthropic & Pexels API keys ...")
from google.colab import userdata
import os

# Retrieve the Anthropic API key from Colab Secrets
anthropic_api_key = userdata.get('ANTHROPIC_API_KEY')
pexels_api_key = userdata.get('PEXELS_API_KEY')

# Set it as an environment variable for phase3_run.py to use
if anthropic_api_key:
    os.environ['ANTHROPIC_API_KEY'] = anthropic_api_key
    print("🔑 Anthropic API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: ANTHROPIC_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")

if pexels_api_key:
    os.environ['PEXELS_API_KEY'] = pexels_api_key
    print("🔑 Pexels API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: PEXELS_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")
# Out:
# Retrieving the Anthropic & Pexels API keys ...
# 🔑 Anthropic API key loaded from secrets and set as environment variable.
# 🔑 Pexels API key loaded from secrets and set as environment variable.

# %%
# Confirm alignment works (interpolation backend — no install needed)
# !python phase3_run.py \
    --script samples/al_askari_script.txt \
    --audio output/al_askari_audio.mp3 \
    --align-only \
    --align-backend interpolated

print("✅ Confirming alignment completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,039 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
# Backend: interpolated
#
# ── Running alignment ──────────────────────────────────────────────
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#
#   Aligned 653 words in 0.0 s
#   Backend used: interpolated
#
# ── First 30 word timings ──────────────────────────────────────────
#      0.00s →    0.71s   (0.71s)   مذكرات
#      0.71s →    1.18s   (0.47s)   جعفر
#      1.18s →    2.01s   (0.83s)   العسكري
#      2.01s →    2.37s   (0.36s)   رجل
#      2.37s →    2.84s   (0.47s)   واحد
#      2.84s →    3.20s   (0.36s)   حمل
#      3.20s →    3.91s   (0.71s)   سلاحاً
#      3.91s →    4.14s   (0.24s)   من
#      4.14s →    4.50s   (0.36s)   أجل
#      4.50s →    5.09s   (0.59s)   تحرير
#      5.09s →    5.68s   (0.59s)   وطنه،
#      5.68s →    6.16s   (0.47s)   لكنه
#      6.16s →    6.87s   (0.71s)   اكتشفَ
#      6.87s →    7.34s   (0.47s)   أنَّ
#      7.34s →    7.81s   (0.47s)   أشرس
#      7.81s →    8.64s   (0.83s)   الأعداء
#      8.64s →    8.88s   (0.24s)   قد
#      8.88s →    9.59s   (0.71s)   يكونون
#      9.59s →    9.83s   (0.24s)   من
#      9.83s →   10.30s   (0.47s)   داخل
#     10.30s →   10.89s   (0.59s)   صفوفك
#     10.89s →   11.25s   (0.36s)   هذه
#     11.25s →   11.72s   (0.47s)   ليست
#     11.72s →   12.31s   (0.59s)   رواية
#     12.31s →   12.78s   (0.47s)   خيال
#     12.78s →   13.61s   (0.83s)   تاريخي،
#     13.61s →   13.85s   (0.24s)   بل
#     13.85s →   14.56s   (0.71s)   شهادةٌ
#     14.56s →   15.15s   (0.59s)   حيّةٌ
#     15.15s →   15.39s   (0.24s)   من
#   … and 623 more
#
# Word timings → output/word_timings.json
# ✅ Confirming alignment completed!

# %%
# Step 1: plan as before — produces output/al_askari_plan_v2.json
# Regenerate the plan with the fixes
# !python phase3_run.py \
    --script  samples/al_askari_script.txt \
    --audio   output/al_askari_audio.mp3 \
    --book-title "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --plan-only \
    --save-plan output/al_askari_plan_v2.json

print("✅ Regenerating the plan completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,039 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
#
# ── Step 1: Forced alignment ───────────────────────────────────────
# WARNING  phase3.align  Backend whisperx failed: No module named 'whisperx'
# WARNING  phase3.align  Backend whisper failed: No module named 'whisper'
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#   653 words aligned via interpolated (0.0s)
#
# ── Step 2: AI shot planner ────────────────────────────────────────
# INFO  phase3.plan  Calling claude-sonnet-4-6 for shot plan (target=65 shots, 4.5s avg, 391.0s total)
# INFO  httpx  HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO  phase3.plan  Clipping shot 381.53-391.00s to 391.00s (audio end)
# INFO  phase3.plan  Merged 1 adjacent identical shot(s) — final plan 61 shots
# INFO  phase3.plan  Plan produced: 61 shots
#   61 shots planned in 115.1s
#
# Plan: 61 shots, 391.0s total
# ────────────────────────────────────────────────────────────────────────────────────────────
# Visuals: typography:20  archive:15  portrait:8  broll:8  section_mark:4  location:3  title_card:2  object:1
# ────────────────────────────────────────────────────────────────────────────────────────────
#     1. [  opening]   0.00-  3.91s ( 3.9s) title_card     static_hold
#     2. [  opening]   3.91-  8.64s ( 4.7s) portrait       slow_push     Jafar al-Askari Iraqi general historical portrait
#     3. [  opening]   8.64- 13.61s ( 5.0s) typography     static_hold   "أشرس الأعداء قد يكونون من داخل صفوفك"
#     4. [  opening]  13.61- 19.18s ( 5.6s) archive        slow_push     Ottoman Empire collapse historical archive photo 1918
#     5. [  opening]  19.18- 24.39s ( 5.2s) typography     static_hold   "مذكراتُ جعفر العسكري"
#     6. [  opening]  24.39- 29.83s ( 5.4s) archive        slow_pull     Ottoman army officers Istanbul early 20th century archive
#     7. [  opening]  29.83- 36.22s ( 6.4s) broll          slow_push     historical Arabic manuscript diary open pages
#     8. [  opening]  36.22- 42.50s ( 6.3s) typography     static_hold   "كيف يصنع العسكري ثورة؟"
#     9. [  opening]  42.50- 50.78s ( 8.3s) portrait       static_hold   Jafar al-Askari Iraqi officer uniform World War One
#    10. [  opening]  50.78- 55.28s ( 4.5s) section_mark   static_hold
#    11. [  opening]  55.28- 59.54s ( 4.3s) location       pan_right     Mosul Iraq historical photograph early 1900s
#    12. [  opening]  59.54- 64.40s ( 4.9s) location       slow_push     Istanbul Constantinople Ottoman skyline historical photo 190
#    13. [  opening]  64.40- 70.67s ( 6.3s) archive        slow_push     Ottoman Military Academy Istanbul students 1905 archive
#    14. [  opening]  70.67- 77.30s ( 6.6s) typography     static_hold   "عبوراً من عالم تقليدي إلى آفاق حديثة مليئة بالمناه"
#    15. [  opening]  77.30- 82.39s ( 5.1s) broll          slow_push     German military training manual 1900s historical
#    16. [  opening]  82.39- 89.49s ( 7.1s) archive        pan_left      Arab officers Ottoman army group portrait 1910 archive
#    17. [  opening]  89.49- 96.48s ( 7.0s) typography     static_hold   "جميعهم يحملون حلماً واحداً"
#    18. [  opening]  96.48-103.23s ( 6.7s) portrait       slow_push     Mahmud Shawkat Pasha Ottoman general historical portrait
#    19. [  opening] 103.23-110.21s ( 7.0s) archive        slow_push     Ottoman army modernisation military parade Istanbul 1908
#    20. [  opening] 110.21-118.85s ( 8.6s) typography     static_hold   "الإصلاح الحقيقي لا يتوقف على التسليح والتَّكْتِيكا"
#    21. [  opening] 118.85-125.60s ( 6.7s) broll          slow_push     Ottoman enlightenment reform era books printing press 1900s
#    22. [  opening] 125.60-133.29s ( 7.7s) typography     static_hold   "طموح جيل كامل آمن أن التعليم والجيش الحديث يمكنهما"
#    23. [  opening] 133.29-141.34s ( 8.0s) archive        pan_right     Arab world education reform early 20th century school archiv
#    24. [  opening] 141.34-146.20s ( 4.9s) section_mark   static_hold
#    25. [  opening] 146.20-150.81s ( 4.6s) archive        fast_push     Committee Union Progress Young Turks secret meeting 1908 arc
#    26. [  opening] 150.81-156.38s ( 5.6s) broll          slow_push     conspiracy shadows political intrigue Ottoman court archival
#    27. [  opening] 156.38-163.24s ( 6.9s) typography     static_hold   "انقلاب ١٩٠٨"
#    28. [  opening] 163.24-169.40s ( 6.2s) archive        slow_push     Sultan Abdulhamid II deposed 1908 Young Turk revolution arch
#    29. [  opening] 169.40-177.09s ( 7.7s) portrait       static_hold   Jafar al-Askari young officer portrait circa 1908
#    30. [  opening] 177.09-183.25s ( 6.2s) typography     static_hold   "التحرر الفكري والتطلع الأوروبي لم يكن كافياً لتحطي"
#    31. [  opening] 183.25-192.25s ( 9.0s) archive        slow_pull     Ottoman political corruption new regime 1910 historical arch
#    32. [  opening] 192.25-200.29s ( 8.0s) broll          slow_push     Ottoman parliament debate political factions 1909 archive
#    33. [  opening] 200.29-210.48s (10.2s) typography     static_hold   "ضابط شاب يؤمن بقوة التغيير، لكنه يرى أمام عينيه كي"
#    34. [  opening] 210.48-218.05s ( 7.6s) portrait       static_hold   Jafar al-Askari pensive portrait historical
#    35. [  opening] 218.05-225.51s ( 7.5s) typography     static_hold   "الطريق الوحيد للخلاص يمر عبر القومية العربية والاس"
#    36. [  opening] 225.51-230.36s ( 4.9s) section_mark   static_hold
#    37. [  opening] 230.36-234.86s ( 4.5s) archive        fast_push     Balkan War Ottoman soldiers 1912 archive photograph
#    38. [  opening] 234.86-240.19s ( 5.3s) archive        slow_push     World War One Middle East front Ottoman forces 1914 archive
#    39. [  opening] 240.19-247.29s ( 7.1s) typography     static_hold   "هل يبقى جندياً وفياً للدولةِ العثمانيةِ المتداعية،"
#    40. [  opening] 247.29-253.45s ( 6.2s) archive        slow_push     Arab Revolt Faisal 1916 Hejaz archive photograph
#    41. [  opening] 253.45-260.08s ( 6.6s) location       pan_right     North Africa Libyan desert Senussi movement 1916 historical
#    42. [  opening] 260.08-266.59s ( 6.5s) archive        slow_push     Senussi fighters Libya World War One archive photo
#    43. [  opening] 266.59-272.74s ( 6.2s) typography     static_hold   "المذكرات تروي بتفاصيل دقيقة كيفية إدارة هذه العملي"
#    44. [  opening] 272.74-279.02s ( 6.3s) broll          slow_push     World War One desert campaign Arabian Peninsula military map
#    45. [  opening] 279.02-287.07s ( 8.0s) portrait       static_hold   Jafar al-Askari commander Arab Revolt portrait 1917
#    46. [  opening] 287.07-293.81s ( 6.7s) typography     static_hold   "تاريخ الشرق الأوسط الحديث مكتوب جزئياً من خلال قرا"
#    47. [  closing] 293.81-296.06s ( 2.2s) section_mark   static_hold
#    48. [  closing] 296.06-300.09s ( 4.0s) broll          slow_push     Arabic history book memoir open pages close-up
#    49. [  closing] 300.09-305.06s ( 5.0s) typography     static_hold   "مذكرات جعفر العسكري ليست كتاب تاريخ عادي يمكنك قرا"
#    50. [  closing] 305.06-310.39s ( 5.3s) archive        slow_pull     Arab nationalism loyalty homeland sacrifice historical archi
#    51. [  closing] 310.39-317.49s ( 7.1s) typography     static_hold   "الثمن الذي يدفعه الأفراد عندما يقفون في تقاطع حتمي"
#    52. [  closing] 317.49-324.35s ( 6.9s) portrait       slow_push     Najda Fathi Safwat Iraqi historian scholar portrait
#    53. [  closing] 324.35-331.46s ( 7.1s) typography     static_hold   "فرصة نادرة للدخول إلى عقل ضابط عاش أهم لحظات التار"
#    54. [  closing] 331.46-338.44s ( 7.0s) object         slow_push     Jafar al-Askari memoirs book cover Arabic edition
#    55. [  closing] 338.44-346.49s ( 8.0s) broll          ken_burns     historical documents maps letters archive Middle East early
#    56. [  closing] 346.49-352.53s ( 6.0s) typography     static_hold   "بين دفتي هذا الكتاب ستجد نقاشاً صريحاً عن الفساد و"
#    57. [  closing] 352.53-360.34s ( 7.8s) archive        slow_push     Iraqi political figures 1920s Baghdad historical archive
#    58. [  closing] 360.34-367.44s ( 7.1s) typography     static_hold   "برجل تَرَدَّدَ وتألَّمَ واختارَ بشجاعة"
#    59. [  closing] 367.44-374.43s ( 7.0s) portrait       static_hold   Jafar al-Askari minister Iraq 1920s official portrait
#    60. [  closing] 374.43-381.53s ( 7.1s) typography     static_hold   "فهم حاضرنا لا يتحقق إلا بفهم عميق لماضينا الذي عاش"
#    61. [  closing] 381.53-391.00s ( 9.5s) title_card     static_hold
#
# Shot plan → output/al_askari_plan_v2.json
# Word timings → output/word_timings.json
# ✅ Regenerating the plan completed!

# %%
# Audit it
# !python audit_plan.py output/al_askari_plan_v2.json
# Expect: ~43 shots, <10% auto-split

print("✅ Audit completed!")
# Out:
# ======================================================================
# PLAN AUDIT
# ======================================================================
#
# Total shots:        61
# Plan timeline:      0.00s → 391.00s (391.0s)
# Average shot:       6.41s
# Range:              2.25s – 10.18s
#
# ✓  No gaps or overlaps
#
# Visual types:
#    typography      20 (  33%) █████████
#    archive         15 (  25%) ███████
#    portrait         8 (  13%) ███
#    broll            8 (  13%) ███
#    section_mark     4 (   7%) █
#    location         3 (   5%) █
#    title_card       2 (   3%)
#    object           1 (   2%)
#
# Motion types:
#    static_hold     31 (  51%) ███████████████
#    slow_push       20 (  33%) █████████
#    slow_pull        3 (   5%) █
#    pan_right        3 (   5%) █
#    fast_push        2 (   3%)
#    pan_left         1 (   2%)
#    ken_burns        1 (   2%)
#
# Section coverage:
#    opening         46 shots
#    closing         15 shots
#
# ✓  Auto-split shots: 1/61 (2%) from 1 original(s)
#      Implied original Sonnet shot count: 61
#
# Typography texts: 26 unique (26 occurrences after splits)
#    Word count: min=2, max=16, avg=9.2
#    Templates: chapter_heading:6, pull_quote:18, name_reveal:1, date_stamp:1
#
#
# Search queries: 35 non-empty, avg 7.5 words
#    ✓ Bare (1–2 words): 0 (none — good specificity)
#
# ======================================================================
# ✅ Audit completed!

# %%
# !python trim_book_cover.py my_book.jpg
# Out:
# Source: my_book.jpg  864×1217  aspect 0.710
# Detected bbox: x [0, 863]  y [0, 1216]  (863×1216)
# With 3.0% margin: 864×1217  aspect 0.710
# Saved: my_book_trimmed.jpg  (322,182 bytes)
#
# Next:
#   python prebuild_assets.py ... --book-cover my_book_trimmed.jpg --book-cover-fit contain

# %%
import os

# Step 2 (NEW): prebuild — run every source, score every candidate,
# write a review dossier.  No video render.
# !python prebuild_assets.py \
    --plan          output/al_askari_plan_v2.json \
    --script        samples/al_askari_script.txt \
    --book-title    "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --anthropic-key "$ANTHROPIC_API_KEY" \
    --pexels-key    "$PEXELS_API_KEY" \
    --review-dir    output/review/ \
    --character-portrait my_jafar.jpg \
    --book-cover my_book_trimmed.jpg \
    --book-cover-fit contain \
    --book-cover-align right

print("🧩 Prebuild completed!")
# Out:
# INFO    phase3.prebuild  Loaded plan: 61 shots
# INFO    phase3.prebuild  Image-needing shots: 35 (the rest are typography)
# INFO    phase3.prebuild  Pinned portrait copied → /content/output/review/overrides/character.jpg
# INFO    phase3.prebuild  Book cover copied → /content/output/review/overrides/book_cover.jpg
# INFO    phase3.prebuild  Shot 2/portrait: query='Jafar al-Askari Iraqi general historical portrait' duration=4.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi general historical portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi general historical portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi general historical portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi general historical portrait'
# INFO    phase3.sources.vision  Vision 2/3/3  Vandalized sculpture in a Baghdad park u  — Monument in Iraq depicting historical/military subject with
# INFO    phase3.sources.vision  Vision 0/2/1  Yemeni groom posing in traditional attir  — Modern costume performance/theatrical portrayal, not histori
# INFO    phase3.sources.vision  Vision 1/2/2  A father and child sitting with a falcon  — Staged historical costume portrait with falcon in desert set
# INFO    phase3.sources  Shot 2: best=Vandalized sculpture in a Baghdad park under a vib (score 8)
# INFO    phase3.prebuild  Shot 4/archive: query='Ottoman Empire collapse historical archive photo 1918' duration=5.6s
# WARNING phase3.sources.loc  LoC search failed for 'Ottoman Empire collapse historical archive photo 1918': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire collapse historical archive photo 1918'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire collapse historical archive photo 1918'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire collapse historical archive photo 1918'
# INFO    phase3.sources.vision  Vision 1/3/2  Stunning aerial view of Topkapi Palace,   — Aerial view of Ottoman-era palace complex (likely Topkapi, I
# INFO    phase3.sources.vision  Vision 2/3/3  Black and white photo of the Hagia Irene  — Ottoman-era architectural style and monumental presence evok
# INFO    phase3.sources.vision  Vision 2/3/3  Elegant view of the Suleymaniye Mosque c  — Ottoman-era mosque architecture matches regional/historical
# INFO    phase3.sources  Shot 4: best=Black and white photo of the Hagia Irene church in (score 8)
# INFO    phase3.prebuild  Shot 6/archive: query='Ottoman army officers Istanbul early 20th century archive' duration=5.4s
# WARNING phase3.sources.loc  LoC search failed for 'Ottoman army officers Istanbul early 20th century archive': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman army officers Istanbul early 20th century archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman army officers Istanbul early 20th century archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman army officers Istanbul early 20th century archive'
# INFO    phase3.sources.vision  Vision 2/3/2  Four soldiers in vintage uniforms with r  — Period military uniforms and composition authentic to early
# INFO    phase3.sources.vision  Vision 2/3/3  The front facade of Istanbul's PTT Museu  — Early 20th century Ottoman architectural context with period
# INFO    phase3.sources.vision  Vision 2/2/3  Historic red brick architecture of the P  — Ottoman-era architecture from correct period and region, but
# INFO    phase3.sources  Shot 6: best=The front facade of Istanbul's PTT Museum with Tur (score 8)
# INFO    phase3.prebuild  Shot 7/broll: query='historical Arabic manuscript diary open pages' duration=6.4s
# WARNING phase3.sources.loc  LoC search failed for 'historical Arabic manuscript diary open pages': HTTP Error 503: Service Unavailable
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical Arabic manuscript diary open pages'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'historical Arabic manuscript diary open pages'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical Arabic manuscript diary open pages'
# INFO    phase3.sources.vision  Vision 2/3/3  Open ancient manuscript on red backgroun  — Historical Arabic manuscript with excellent lighting and com
# INFO    phase3.sources.vision  Vision 2/3/3  Detailed view of an ancient illuminated   — Authentic historical Arabic manuscript with ornate bindings
# INFO    phase3.sources.vision  Vision 3/2/2  A close-up of an antique open book with   — Authentic historical Arabic manuscript diary with period-app
# INFO    phase3.sources  Shot 7: best=Open ancient manuscript on red background displaye (score 8)
# INFO    phase3.prebuild  Shot 9/portrait: query='Jafar al-Askari Iraqi officer uniform World War One' duration=8.3s
# WARNING phase3.sources.loc  LoC search failed for 'Jafar al-Askari Iraqi officer uniform World War One': HTTP Error 503: Service Unavailable
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi officer uniform World War One'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi officer uniform World War One'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi officer uniform World War One'
# INFO    phase3.sources.vision  Vision 2/3/3  Two riders in military attire on horseba  — Period-appropriate WWI military uniform and cavalry setting
# INFO    phase3.sources.vision  Vision 2/3/3  A sepia-toned image of a historical reen  — Period-appropriate WWI officer uniform and equipment in sepi
# INFO    phase3.sources.vision  Vision 2/3/3  A soldier in uniform holding a rifle aga  — WWI-era military uniform and rifle are historically appropri
# INFO    phase3.sources  Shot 9: best=Two riders in military attire on horseback, set in (score 8)
# INFO    phase3.prebuild  Shot 11/location: query='Mosul Iraq historical photograph early 1900s' duration=4.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mosul Iraq historical photograph early 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mosul Iraq historical photograph early 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mosul Iraq historical photograph early 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mosul Iraq historical photograph early 1900s'
# INFO    phase3.sources.vision  Vision 2/2/2  Explore the historic ruins of ancient Ba  — Depicts historical Middle Eastern architecture and landscape
# INFO    phase3.sources.vision  Vision 2/2/2  A striking black and white aerial view s  — Early 20th-century Middle Eastern urban landscape with perio
# INFO    phase3.sources.vision  Vision 2/3/3  Explore the historic architecture and st  — Authentic Mosul cityscape with minaret and historical archit
# INFO    phase3.sources  Shot 11: best=Explore the historic architecture and stunning lan (score 8)
# INFO    phase3.prebuild  Shot 12/location: query='Istanbul Constantinople Ottoman skyline historical photo 190' duration=4.9s
# WARNING phase3.sources.loc  LoC search failed for 'Istanbul Constantinople Ottoman skyline historical photo 1900': HTTP Error 503: Service Unavailable
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Istanbul Constantinople Ottoman skyline historical photo 1900'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Istanbul Constantinople Ottoman skyline historical photo 1900'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Istanbul Constantinople Ottoman skyline historical photo 1900'
# INFO    phase3.sources.vision  Vision 3/2/3  Grayscale image capturing the iconic Hag  — Authentic early 1900s Istanbul skyline with Hagia Sophia and
# INFO    phase3.sources.vision  Vision 3/2/2  Scenic view of Istanbul's skyline featur  — Authentic Istanbul skyline with recognizable Ottoman mosques
# INFO    phase3.sources.vision  Vision 3/2/2  A picturesque view of the Hagia Sophia a  — Authentic Istanbul skyline with Hagia Sophia and minarets ma
# INFO    phase3.sources  Shot 12: best=Grayscale image capturing the iconic Hagia Sophia  (score 8)
# INFO    phase3.prebuild  Shot 13/archive: query='Ottoman Military Academy Istanbul students 1905 archive' duration=6.3s
# WARNING phase3.sources.loc  LoC search failed for 'Ottoman Military Academy Istanbul students 1905 archive': HTTP Error 503: Service Unavailable
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Military Academy Istanbul students 1905 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 1 candidates for 'Ottoman Military Academy Istanbul students 1905 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Military Academy Istanbul students 1905 archive'
# WARNING phase3.sources.base  Source internet_archive: download failed for https://archive.org/download/dr_-------operational-map-of-the-anatolian-10841000: HTTP Error 404: Not Found
# INFO    phase3.sources.vision  Vision 2/3/3  Historic Kuleli Military School on the B  — Ottoman-era architecture in Istanbul matches region and era,
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze military statues from Ottoman era, right region/perio
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — Ottoman-era military figure on horseback in appropriate peri
# INFO    phase3.sources  Shot 13: best=Historic Kuleli Military School on the Bosphorus i (score 8)
# INFO    phase3.prebuild  Shot 15/broll: query='German military training manual 1900s historical' duration=5.1s
# WARNING phase3.sources.loc  LoC search failed for 'German military training manual 1900s historical': HTTP Error 503: Service Unavailable
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'German military training manual 1900s historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'German military training manual 1900s historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'German military training manual 1900s historical'
# INFO    phase3.sources.vision  Vision 1/3/2  Historic US Army checkpoint at Berlin's   — Cold War checkpoint is wrong era/region for Ottoman-era mili
# INFO    phase3.sources.vision  Vision 1/2/2  Men in vintage military uniforms recreat  — Period military costume and rifles suggest early 1900s train
# INFO    phase3.sources.vision  Vision 0/2/2  A vintage steam train travels through Ka  — Image shows a heritage steam train in contemporary European
# INFO    phase3.sources  Shot 15: best=Historic US Army checkpoint at Berlin's Mauermuseu (score 6)
# INFO    phase3.prebuild  Shot 16/archive: query='Arab officers Ottoman army group portrait 1910 archive' duration=7.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab officers Ottoman army group portrait 1910 archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab officers Ottoman army group portrait 1910 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab officers Ottoman army group portrait 1910 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab officers Ottoman army group portrait 1910 archive'
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — Depicts a uniformed officer on horseback in early 1900s Otto
# INFO    phase3.sources.vision  Vision 1/2/2  Syrian army soldiers in a parade in Dama  — Modern military parade with horse-mounted officer and Syrian
# INFO    phase3.sources.vision  Vision 1/3/2  A military parade of the Chilean Carabin  — Modern military ceremony with period-style uniforms, not arc
# INFO    phase3.sources  Shot 16: best=Sepia-toned vintage photo of a man in uniform ridi (score 6)
# INFO    phase3.prebuild  Shot 18/portrait: query='Mahmud Shawkat Pasha Ottoman general historical portrait' duration=6.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.vision  Vision 1/3/3  View of the detailed dome and Arabic cal  — Ottoman architectural interior beautifully captured but unre
# INFO    phase3.sources.vision  Vision 1/3/3  Majestic view of Ishak Pasha Palace in D  — Ottoman-era fortress in correct geographic/historical region
# INFO    phase3.sources.vision  Vision 1/3/3  Explore the intricate architecture and d  — Ottoman architectural interior is period-appropriate for ear
# INFO    phase3.sources  Shot 18: best=View of the detailed dome and Arabic calligraphy i (score 7)
# INFO    phase3.prebuild  Shot 19/archive: query='Ottoman army modernisation military parade Istanbul 1908' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman army modernisation military parade Istanbul 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman army modernisation military parade Istanbul 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman army modernisation military parade Istanbul 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman army modernisation military parade Istanbul 1908'
# INFO    phase3.sources.vision  Vision 1/2/2  A formal military parade with soldiers i  — Military parade with uniformed troops in formation on dusty
# INFO    phase3.sources.vision  Vision 1/2/2  Group of Turkish soldiers in uniform and  — Modern military parade with correct regional uniform style,
# INFO    phase3.sources.vision  Vision 2/3/3  Romanian soldiers in traditional uniform  — Modern military parade with Ottoman-style uniforms and perio
# INFO    phase3.sources  Shot 19: best=Romanian soldiers in traditional uniforms marching (score 8)
# INFO    phase3.prebuild  Shot 21/broll: query='Ottoman enlightenment reform era books printing press 1900s' duration=6.7s
# WARNING phase3.sources.loc  LoC search failed for 'Ottoman enlightenment reform era books printing press 1900s': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman enlightenment reform era books printing press 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman enlightenment reform era books printing press 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman enlightenment reform era books printing press 1900s'
# INFO    phase3.sources.vision  Vision 1/2/2  A cluttered vintage print shop interior   — Cluttered study/archive space evokes early 20th-century inte
# INFO    phase3.sources.vision  Vision 2/3/3  A cozy flat lay of open books, fresh lea  — Captures early 20th century Ottoman-era Turkish periodicals
# INFO    phase3.sources.vision  Vision 2/3/3  A collection of vintage books displayed   — Classic books evoke the Ottoman intellectual era and printin
# INFO    phase3.sources  Shot 21: best=A cozy flat lay of open books, fresh leaves, and a (score 8)
# INFO    phase3.prebuild  Shot 23/archive: query='Arab world education reform early 20th century school archiv' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab world education reform early 20th century school archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab world education reform early 20th century school archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab world education reform early 20th century school archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab world education reform early 20th century school archive'
# INFO    phase3.sources.vision  Vision 2/3/3  A collection of antique books stacked on  — Vintage stacked books with warm tones evoke early 20th centu
# INFO    phase3.sources.vision  Vision 2/2/3  Vintage family photographs with daisies   — Early 20th century archive photograph with authentic period
# INFO    phase3.sources.vision  Vision 3/2/2  Retro black and white photo of office wo  — Authentic early 20th century classroom scene with multiple f
# INFO    phase3.sources  Shot 23: best=A collection of antique books stacked on a warm cr (score 8)
# INFO    phase3.prebuild  Shot 25/archive: query='Committee Union Progress Young Turks secret meeting 1908 arc' duration=4.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Committee Union Progress Young Turks secret meeting 1908 archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Committee Union Progress Young Turks secret meeting 1908 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Committee Union Progress Young Turks secret meeting 1908 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Committee Union Progress Young Turks secret meeting 1908 archive'
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of hand holding top secret docu  — Generic archival package evokes historical documentation era
# INFO    phase3.sources.vision  Vision 1/2/2  Stylish young woman poses at İstanbul's   — Modern portrait in institutional setting with Turkish signag
# INFO    phase3.sources.vision  Vision 1/2/3  A dramatic scene in an ornate dining roo  — Staged dramatic scene with period atmosphere and ornate sett
# INFO    phase3.sources  Shot 25: best=A dramatic scene in an ornate dining room featurin (score 6)
# INFO    phase3.prebuild  Shot 26/broll: query='conspiracy shadows political intrigue Ottoman court archival' duration=5.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'conspiracy shadows political intrigue Ottoman court archival'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'conspiracy shadows political intrigue Ottoman court archival'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'conspiracy shadows political intrigue Ottoman court archival'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'conspiracy shadows political intrigue Ottoman court archival'
# INFO    phase3.sources.vision  Vision 3/2/3  An old Russian document placed inside an  — Authentic archival document with handwritten notations in Ar
# INFO    phase3.sources.vision  Vision 2/3/2  Stone-built Ottoman era tomb in Göynük,   — Ottoman-era stone architecture in appropriate regional style
# INFO    phase3.sources.vision  Vision 1/3/2  Turkish national flag waving under a clo  — Turkish flag is geographically/temporally related to Ottoman
# INFO    phase3.sources  Shot 26: best=An old Russian document placed inside an archive b (score 8)
# INFO    phase3.prebuild  Shot 28/archive: query='Sultan Abdulhamid II deposed 1908 Young Turk revolution arch' duration=6.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Sultan Abdulhamid II deposed 1908 Young Turk revolution archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Sultan Abdulhamid II deposed 1908 Young Turk revolution archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Sultan Abdulhamid II deposed 1908 Young Turk revolution archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Sultan Abdulhamid II deposed 1908 Young Turk revolution archive'
# INFO    phase3.sources.vision  Vision 1/2/2  A serene street in Heybeliada, featuring  — Ottoman-era architecture and Turkish flag evoke the right ge
# INFO    phase3.sources.vision  Vision 1/3/3  Massive gathering at Anıtkabir, Ankara,   — Modern mass gathering with Turkish flags; right region and e
# INFO    phase3.sources.vision  Vision 1/2/2  Entrance of Ahmet Hamdi Tanpinar library  — Ottoman-era building with period architecture fits the geogr
# INFO    phase3.sources  Shot 28: best=Massive gathering at Anıtkabir, Ankara, featuring  (score 7)
# INFO    phase3.prebuild  Shot 29/portrait: query='Jafar al-Askari young officer portrait circa 1908' duration=7.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari young officer portrait circa 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari young officer portrait circa 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari young officer portrait circa 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari young officer portrait circa 1908'
# INFO    phase3.sources.vision  Vision 0/2/1  A young man with an Arabian horse in Al-  — Contemporary portrait of a young man with a horse; no histor
# INFO    phase3.sources.vision  Vision 1/3/2  Yemeni groom posing in traditional attir  — Modern theatrical costume portrait with period styling eleme
# INFO    phase3.sources.vision  Vision 0/2/1  A man in traditional Yemeni dress poses   — Modern costumed performer on stage set, not a historical pho
# INFO    phase3.sources  Shot 29: best=Yemeni groom posing in traditional attire with rif (score 6)
# INFO    phase3.prebuild  Shot 31/archive: query='Ottoman political corruption new regime 1910 historical arch' duration=9.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman political corruption new regime 1910 historical archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman political corruption new regime 1910 historical archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman political corruption new regime 1910 historical archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman political corruption new regime 1910 historical archive'
# INFO    phase3.sources.vision  Vision 2/3/2  Turkish national flag waving under a clo  — Turkish flag represents Ottoman successor state and regional
# INFO    phase3.sources.vision  Vision 2/3/2  Majestic statue of Atatürk on horseback   — Ottoman-era equestrian monument in Middle Eastern setting ma
# INFO    phase3.sources.vision  Vision 1/2/2  Crowd at a public rally with Turkish fla  — Modern Turkish flag and mosque scene are geographically rele
# INFO    phase3.sources  Shot 31: best=Turkish national flag waving under a cloudy sky, s (score 7)
# INFO    phase3.prebuild  Shot 32/broll: query='Ottoman parliament debate political factions 1909 archive' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman parliament debate political factions 1909 archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman parliament debate political factions 1909 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman parliament debate political factions 1909 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman parliament debate political factions 1909 archive'
# INFO    phase3.sources.vision  Vision 3/3/2  An empty parliamentary meeting room with  — Authentic Ottoman-era parliament chamber with period archite
# INFO    phase3.sources.vision  Vision 2/3/3  A luxurious interior view of a legislati  — Ottoman-era parliament chamber evokes the 1909 setting and p
# INFO    phase3.sources.vision  Vision 2/3/3  A detailed view of an empty legislative   — Parliamentary chamber matches Ottoman era setting and politi
# INFO    phase3.sources  Shot 32: best=An empty parliamentary meeting room with wooden se (score 8)
# INFO    phase3.prebuild  Shot 34/portrait: query='Jafar al-Askari pensive portrait historical' duration=7.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari pensive portrait historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari pensive portrait historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari pensive portrait historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari pensive portrait historical'
# INFO    phase3.sources.vision  Vision 2/3/3  A man in traditional attire reflecting i  — Authentic period-appropriate Middle Eastern setting with con
# INFO    phase3.sources.vision  Vision 1/3/3  Black and white portrait of an adult wit  — Evocative black-and-white portrait with period costume and p
# INFO    phase3.sources.vision  Vision 2/3/3  Middle Eastern man reading Quran in Kuwa  — Evocative portrait of a man in traditional Arab dress readin
# INFO    phase3.sources  Shot 34: best=A man in traditional attire reflecting inside a mo (score 8)
# INFO    phase3.prebuild  Shot 37/archive: query='Balkan War Ottoman soldiers 1912 archive photograph' duration=4.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Balkan War Ottoman soldiers 1912 archive photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Balkan War Ottoman soldiers 1912 archive photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Balkan War Ottoman soldiers 1912 archive photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Balkan War Ottoman soldiers 1912 archive photograph'
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — Early 20th century mounted soldier in Ottoman-era uniform ma
# INFO    phase3.sources.vision  Vision 1/3/2  A group of men in white uniforms partici  — Modern reenactment of period soldiers with authentic uniform
# INFO    phase3.sources.vision  Vision 1/3/2  Two soldiers in historical uniforms posi  — Modern reenactment photo with period costume elements, not a
# INFO    phase3.sources  Shot 37: best=Sepia-toned vintage photo of a man in uniform ridi (score 6)
# INFO    phase3.prebuild  Shot 38/archive: query='World War One Middle East front Ottoman forces 1914 archive' duration=5.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'World War One Middle East front Ottoman forces 1914 archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'World War One Middle East front Ottoman forces 1914 archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'World War One Middle East front Ottoman forces 1914 archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'World War One Middle East front Ottoman forces 1914 archive'
# INFO    phase3.sources.vision  Vision 2/2/3  Bronze soldier statue with bayonet, symb  — WWI-era soldier statue evokes the period and region but is a
# INFO    phase3.sources.vision  Vision 2/3/3  A soldier in uniform holding a rifle aga  — WWI-era Ottoman soldier portrait with period-accurate unifor
# INFO    phase3.sources.vision  Vision 1/3/2  Scenic view of Topkapi Palace across the  — Ottoman-era waterfront architecture visible but lacks specif
# INFO    phase3.sources  Shot 38: best=A soldier in uniform holding a rifle against a dra (score 8)
# INFO    phase3.prebuild  Shot 40/archive: query='Arab Revolt Faisal 1916 Hejaz archive photograph' duration=6.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab Revolt Faisal 1916 Hejaz archive photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab Revolt Faisal 1916 Hejaz archive photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab Revolt Faisal 1916 Hejaz archive photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab Revolt Faisal 1916 Hejaz archive photograph'
# INFO    phase3.sources.vision  Vision 2/2/2  A captivating vintage army photo in a se  — Period-appropriate archival photograph of a group from early
# INFO    phase3.sources.vision  Vision 2/2/2  Explore vintage family photo albums fill  — Period-appropriate archival photographs from early 20th cent
# INFO    phase3.sources.vision  Vision 2/2/2  A collection of vintage black-and-white   — Period-appropriate archival photographs from early 20th cent
# INFO    phase3.sources  Shot 40: best=A captivating vintage army photo in a sepia-toned  (score 6)
# INFO    phase3.prebuild  Shot 41/location: query='North Africa Libyan desert Senussi movement 1916 historical' duration=6.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'North Africa Libyan desert Senussi movement 1916 historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'North Africa Libyan desert Senussi movement 1916 historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'North Africa Libyan desert Senussi movement 1916 historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'North Africa Libyan desert Senussi movement 1916 historical'
# INFO    phase3.sources.vision  Vision 2/2/2  Old ruins in Matrouh, Egypt with a lush   — North African desert ruins with oasis settlement match geogr
# INFO    phase3.sources.vision  Vision 2/3/3  A stunning view of Taghit village and sa  — Authentic North African desert kasbah with Saharan landscape
# INFO    phase3.sources.vision  Vision 2/3/3  A man walking past ancient cave dwelling  — Authentic North African desert architecture with period-appr
# INFO    phase3.sources  Shot 41: best=A stunning view of Taghit village and sand dunes i (score 8)
# INFO    phase3.prebuild  Shot 42/archive: query='Senussi fighters Libya World War One archive photo' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Senussi fighters Libya World War One archive photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Senussi fighters Libya World War One archive photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Senussi fighters Libya World War One archive photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Senussi fighters Libya World War One archive photo'
# INFO    phase3.sources.vision  Vision 2/2/2  Sepia-toned vintage photo of a man in un  — WWI-era mounted soldier in appropriate theater and timeframe
# INFO    phase3.sources.vision  Vision 2/3/3  Two riders in military attire on horseba  — Period-appropriate WWI-era cavalry scene with authentic unif
# INFO    phase3.sources.vision  Vision 1/2/2  Silhouette view through the interior of   — Modern abandoned vehicle interior with distant cityscape; ev
# INFO    phase3.sources  Shot 42: best=Two riders in military attire on horseback, set in (score 8)
# INFO    phase3.prebuild  Shot 44/broll: query='World War One desert campaign Arabian Peninsula military map' duration=6.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'World War One desert campaign Arabian Peninsula military map 1916'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'World War One desert campaign Arabian Peninsula military map 1916'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'World War One desert campaign Arabian Peninsula military map 1916'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'World War One desert campaign Arabian Peninsula military map 1916'
# INFO    phase3.sources.vision  Vision 1/3/2  Vintage cannon displayed outdoors at a m  — Historic cannon in period architecture evokes military era a
# INFO    phase3.sources.vision  Vision 1/3/2  Footprints trail across a pristine, whit  — Desert beach with footprints evokes Arabian Peninsula, but l
# INFO    phase3.sources.vision  Vision 2/3/3  A group of camels strolling through the   — Desert landscape with camels evokes Arabian Peninsula settin
# INFO    phase3.sources  Shot 44: best=A group of camels strolling through the Dubai dese (score 8)
# INFO    phase3.prebuild  Shot 45/portrait: query='Jafar al-Askari commander Arab Revolt portrait 1917' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari commander Arab Revolt portrait 1917'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari commander Arab Revolt portrait 1917'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari commander Arab Revolt portrait 1917'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari commander Arab Revolt portrait 1917'
# INFO    phase3.sources.vision  Vision 1/2/1  A man in traditional Yemeni dress poses   — Modern costume recreation of historical figure in contempora
# INFO    phase3.sources.vision  Vision 1/3/3  A man in period costume poses outdoors i  — Styled portrait with period military uniform and architectur
# INFO    phase3.sources.vision  Vision 0/2/1  Yemeni groom posing in traditional attir  — Modern costume recreation or theatrical performance, not his
# INFO    phase3.sources  Shot 45: best=A man in period costume poses outdoors in Buenos A (score 7)
# INFO    phase3.prebuild  Shot 48/broll: query='Arabic history book memoir open pages close-up' duration=4.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arabic history book memoir open pages close-up'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arabic history book memoir open pages close-up'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arabic history book memoir open pages close-up'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arabic history book memoir open pages close-up'
# INFO    phase3.sources.vision  Vision 3/3/3  Black and white photo of an open Arabic   — Perfect match: open Arabic manuscript with dramatic close-up
# INFO    phase3.sources.vision  Vision 3/2/2  Close-up view of Arabic script on a book  — Authentic Arabic historical text with shallow depth-of-field
# INFO    phase3.sources.vision  Vision 3/2/2  Detailed close-up of Arabic text on an o  — Authentic Arabic manuscript page with shallow focus creates
# INFO    phase3.sources  Shot 48: best=Black and white photo of an open Arabic book with  (score 9)
# INFO    phase3.prebuild  Shot 50/archive: query='Arab nationalism loyalty homeland sacrifice historical archi' duration=5.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab nationalism loyalty homeland sacrifice historical archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab nationalism loyalty homeland sacrifice historical archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab nationalism loyalty homeland sacrifice historical archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab nationalism loyalty homeland sacrifice historical archive'
# INFO    phase3.sources.vision  Vision 1/2/2  Vibrant crowd at Anıtkabir in Ankara, sh  — Modern Turkish flag at contemporary rally—wrong era and nati
# INFO    phase3.sources.vision  Vision 3/2/3  Detailed close-up of the Saudi Arabian f  — Saudi flag with sword is iconographically perfect for Arab n
# INFO    phase3.sources.vision  Vision 1/3/2  Soldiers performing a ceremonial march i  — Modern military ceremony at Anitkabir (Turkish monument) is
# INFO    phase3.sources  Shot 50: best=Detailed close-up of the Saudi Arabian flag showca (score 8)
# INFO    phase3.prebuild  Shot 52/portrait: query='Najda Fathi Safwat Iraqi historian scholar portrait' duration=6.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Najda Fathi Safwat Iraqi historian scholar portrait'
# INFO    phase3.sources.vision  Vision 0/2/2  Close-up of a middle-eastern woman in a   — Portrait shows a woman in traditional headwear framed throug
# INFO    phase3.sources.vision  Vision 0/2/2  Young graduate woman smiling in cap and   — Image shows a contemporary graduation portrait, not a histor
# INFO    phase3.sources.vision  Vision 1/3/3  Black and white photo of a man reading i  — Black-and-white portrait of a man reading in a library setti
# INFO    phase3.sources  Shot 52: best=Black and white photo of a man reading in a vintag (score 7)
# INFO    phase3.prebuild  Shot 54/object: query='Jafar al-Askari memoirs book cover Arabic edition' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari memoirs book cover Arabic edition'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari memoirs book cover Arabic edition'
# INFO    phase3.sources.vision  Vision 2/3/3  Close-up of a Quran with intricate gold   — Islamic religious text with ornate Arabic calligraphy on blu
# INFO    phase3.sources.vision  Vision 3/3/3  Islamic Holy Quran book with ornate gold  — Ornate Islamic manuscript cover with green seal and gold fil
# INFO    phase3.sources.vision  Vision 3/3/3  Three Qurans with ornate covers displaye  — Three red leather-bound volumes with ornate gold Arabic call
# INFO    phase3.sources  Shot 54: best=Islamic Holy Quran book with ornate gold detailing (score 9)
# INFO    phase3.prebuild  Shot 55/broll: query='historical documents maps letters archive Middle East early ' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'historical documents maps letters archive Middle East early 20th century'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical documents maps letters archive Middle East early 20th century'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'historical documents maps letters archive Middle East early 20th century'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical documents maps letters archive Middle East early 20th century'
# INFO    phase3.sources.vision  Vision 3/3/3  A nostalgic flat lay combining vintage t  — Perfectly matched period-appropriate composition with vintag
# INFO    phase3.sources.vision  Vision 3/3/3  A vintage map featuring a page from the   — Authentic period map and historical document (Cyrillic text
# INFO    phase3.sources.vision  Vision 3/2/3  A close-up of a vintage map, magnifying   — Authentic historical archive aesthetic with vintage maps, ma
# INFO    phase3.sources  Shot 55: best=A nostalgic flat lay combining vintage travel item (score 9)
# INFO    phase3.prebuild  Shot 57/archive: query='Iraqi political figures 1920s Baghdad historical archive' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Iraqi political figures 1920s Baghdad historical archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Iraqi political figures 1920s Baghdad historical archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Iraqi political figures 1920s Baghdad historical archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Iraqi political figures 1920s Baghdad historical archive'
# INFO    phase3.sources.vision  Vision 1/3/3  Vandalized sculpture in a Baghdad park u  — Modern commemorative monument in Baghdad park; right region
# INFO    phase3.sources.vision  Vision 2/3/3  Stunning view of traditional architectur  — Architectural interior from early 20th-century Baghdad era w
# INFO    phase3.sources.vision  Vision 1/3/2  Man in a tuxedo smiling indoors in a lux  — Modern formal portrait in elegant interior; right era aesthe
# INFO    phase3.sources  Shot 57: best=Stunning view of traditional architecture in Baghd (score 8)
# INFO    phase3.prebuild  Shot 59/portrait: query='Jafar al-Askari minister Iraq 1920s official portrait' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari minister Iraq 1920s official portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari minister Iraq 1920s official portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari minister Iraq 1920s official portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari minister Iraq 1920s official portrait'
# INFO    phase3.sources.vision  Vision 0/3/3  Female judge in courtroom setting, sitti  — Modern staged courtroom scene with contemporary styling; unr
# INFO    phase3.sources.vision  Vision 2/3/3  A senior judge stands at the podium in a  — Formal ministerial portrait from appropriate era with strong
# INFO    phase3.sources.vision  Vision 1/2/2  Judge in traditional attire sits at a co  — Contemporary styled office scene with legal/governmental aes
# INFO    phase3.sources  Shot 59: best=A senior judge stands at the podium in a courtroom (score 8)
# INFO    phase3.sources.decisions  Decisions written → /content/output/review/decisions.json
#
# ────────────────────────────────────────────────────────────────
# Review dossier ready: /content/output/review
# Image shots processed:  35
#   with a chosen winner: 35
#   with no candidates:   0
# Winner source breakdown:
#   pexels           35
# Pinned portrait:        overrides/character.jpg
#   affects 8 portrait shot(s) at render time
# Book cover:             overrides/book_cover.jpg
#   fit mode:             contain
#   align:                right
#   affects 2 title-card shot(s) at render time
#
# Next:
#   1. Open /content/output/review/ and review each shot folder.
#   2. Edit /content/output/review/decisions.json to swap candidates,
#      drop overrides into /content/output/review/overrides/,
#      or set 'pinned_portrait'.
#   3. Render:
#      python render_plan.py --plan output/al_askari_plan_v2.json \
#          --review-dir /content/output/review \
#          --audio <audio> --output <output.mp4>
# ────────────────────────────────────────────────────────────────
# 🧩 Prebuild completed!

# %%
import os
import zipfile

output_dir = 'output/review'
zip_filename = 'review.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            file_path = os.path.join(root, file)
            # Add file to zip, preserving directory structure relative to 'output_dir'
            # Skip .mp3 files if any exist (though unlikely in review folder)
            if not file_path.endswith('.mp3'):
                zipf.write(file_path, os.path.relpath(file_path, output_dir))
                files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing: ")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print("  (No files found to zip in the 'output/review' directory.)")
# Out:
# 🤐 Successfully created 'review.zip' containing:
#   - output/review/README.txt
#   - output/review/decisions.json
#   - output/review/shot_02_portrait/pexels_c.jpg
#   - output/review/shot_02_portrait/context.txt
#   - output/review/shot_02_portrait/candidates.json
#   - output/review/shot_02_portrait/pexels_b.jpg
#   - output/review/shot_02_portrait/pexels_a.jpg
#   - output/review/shot_16_archive/pexels_c.jpg
#   - output/review/shot_16_archive/context.txt
#   - output/review/shot_16_archive/candidates.json
#   - output/review/shot_16_archive/pexels_b.jpg
#   - output/review/shot_16_archive/pexels_a.jpg
#   - output/review/shot_54_object/pexels_c.png
#   - output/review/shot_54_object/context.txt
#   - output/review/shot_54_object/candidates.json
#   - output/review/shot_54_object/pexels_b.png
#   - output/review/shot_54_object/pexels_a.jpg
#   - output/review/shot_06_archive/pexels_c.jpg
#   - output/review/shot_06_archive/context.txt
#   - output/review/shot_06_archive/candidates.json
#   - output/review/shot_06_archive/pexels_b.jpg
#   - output/review/shot_06_archive/pexels_a.jpg
#   - output/review/shot_23_archive/pexels_c.jpg
#   - output/review/shot_23_archive/context.txt
#   - output/review/shot_23_archive/candidates.json
#   - output/review/shot_23_archive/pexels_b.jpg
#   - output/review/shot_23_archive/pexels_a.jpg
#   - output/review/shot_59_portrait/pexels_c.jpg
#   - output/review/shot_59_portrait/context.txt
#   - output/review/shot_59_portrait/candidates.json
#   - output/review/shot_59_portrait/pexels_b.jpg
#   - output/review/shot_59_portrait/pexels_a.jpg
#   - output/review/shot_34_portrait/pexels_a.png
#   - output/review/shot_34_portrait/pexels_c.png
#   - output/review/shot_34_portrait/context.txt
#   - output/review/shot_34_portrait/candidates.json
#   - output/review/shot_34_portrait/pexels_b.jpg
#   - output/review/shot_07_broll/pexels_c.jpg
#   - output/review/shot_07_broll/context.txt
#   - output/review/shot_07_broll/candidates.json
#   - output/review/shot_07_broll/pexels_b.jpg
#   - output/review/shot_07_broll/pexels_a.jpg
#   - output/review/shot_18_portrait/pexels_c.jpg
#   - output/review/shot_18_portrait/context.txt
#   - output/review/shot_18_portrait/candidates.json
#   - output/review/shot_18_portrait/pexels_b.png
#   - output/review/shot_18_portrait/pexels_a.jpg
#   - output/review/shot_09_portrait/pexels_c.jpg
#   - output/review/shot_09_portrait/context.txt
#   - output/review/shot_09_portrait/candidates.json
#   - output/review/shot_09_portrait/pexels_b.jpg
#   - output/review/shot_09_portrait/pexels_a.jpg
#   - output/review/shot_44_broll/pexels_c.jpg
#   - output/review/shot_44_broll/context.txt
#   - output/review/shot_44_broll/candidates.json
#   - output/review/shot_44_broll/pexels_b.jpg
#   - output/review/shot_44_broll/pexels_a.jpg
#   - output/review/shot_28_archive/pexels_c.jpg
#   - output/review/shot_28_archive/context.txt
#   - output/review/shot_28_archive/candidates.json
#   - output/review/shot_28_archive/pexels_b.jpg
#   - output/review/shot_28_archive/pexels_a.jpg
#   - output/review/shot_15_broll/pexels_c.jpg
#   - output/review/shot_15_broll/context.txt
#   - output/review/shot_15_broll/candidates.json
#   - output/review/shot_15_broll/pexels_b.jpg
#   - output/review/shot_15_broll/pexels_a.jpg
#   - output/review/shot_50_archive/pexels_c.jpg
#   - output/review/shot_50_archive/context.txt
#   - output/review/shot_50_archive/candidates.json
#   - output/review/shot_50_archive/pexels_b.jpg
#   - output/review/shot_50_archive/pexels_a.jpg
#   - output/review/shot_12_location/pexels_c.jpg
#   - output/review/shot_12_location/context.txt
#   - output/review/shot_12_location/candidates.json
#   - output/review/shot_12_location/pexels_b.jpg
#   - output/review/shot_12_location/pexels_a.jpg
#   - output/review/shot_26_broll/pexels_c.jpg
#   - output/review/shot_26_broll/context.txt
#   - output/review/shot_26_broll/candidates.json
#   - output/review/shot_26_broll/pexels_b.jpg
#   - output/review/shot_26_broll/pexels_a.jpg
#   - output/review/shot_04_archive/pexels_c.jpg
#   - output/review/shot_04_archive/context.txt
#   - output/review/shot_04_archive/candidates.json
#   - output/review/shot_04_archive/pexels_b.jpg
#   - output/review/shot_04_archive/pexels_a.jpg
#   - output/review/shot_57_archive/pexels_c.jpg
#   - output/review/shot_57_archive/context.txt
#   - output/review/shot_57_archive/candidates.json
#   - output/review/shot_57_archive/pexels_b.jpg
#   - output/review/shot_57_archive/pexels_a.jpg
#   - output/review/shot_29_portrait/pexels_c.jpg
#   - output/review/shot_29_portrait/context.txt
#   - output/review/shot_29_portrait/candidates.json
#   - output/review/shot_29_portrait/pexels_b.jpg
#   - output/review/shot_29_portrait/pexels_a.jpg
#   - output/review/shot_40_archive/pexels_c.jpg
#   - output/review/shot_40_archive/context.txt
#   - output/review/shot_40_archive/candidates.json
#   - output/review/shot_40_archive/pexels_b.jpg
#   - output/review/shot_40_archive/pexels_a.jpg
#   - output/review/shot_13_archive/pexels_c.jpg
#   - output/review/shot_13_archive/context.txt
#   - output/review/shot_13_archive/candidates.json
#   - output/review/shot_13_archive/pexels_b.jpg
#   - output/review/shot_13_archive/pexels_a.jpg
#   - output/review/shot_48_broll/pexels_c.jpg
#   - output/review/shot_48_broll/context.txt
#   - output/review/shot_48_broll/candidates.json
#   - output/review/shot_48_broll/pexels_b.jpg
#   - output/review/shot_48_broll/pexels_a.jpg
#   - output/review/shot_19_archive/pexels_c.jpg
#   - output/review/shot_19_archive/context.txt
#   - output/review/shot_19_archive/candidates.json
#   - output/review/shot_19_archive/pexels_b.jpg
#   - output/review/shot_19_archive/pexels_a.jpg
#   - output/review/shot_42_archive/pexels_c.jpg
#   - output/review/shot_42_archive/context.txt
#   - output/review/shot_42_archive/candidates.json
#   - output/review/shot_42_archive/pexels_b.jpg
#   - output/review/shot_42_archive/pexels_a.jpg
#   - output/review/shot_37_archive/pexels_c.jpg
#   - output/review/shot_37_archive/context.txt
#   - output/review/shot_37_archive/candidates.json
#   - output/review/shot_37_archive/pexels_b.jpg
#   - output/review/shot_37_archive/pexels_a.jpg
#   - output/review/shot_31_archive/pexels_c.jpg
#   - output/review/shot_31_archive/context.txt
#   - output/review/shot_31_archive/candidates.json
#   - output/review/shot_31_archive/pexels_b.jpg
#   - output/review/shot_31_archive/pexels_a.jpg
#   - output/review/shot_52_portrait/pexels_c.jpg
#   - output/review/shot_52_portrait/context.txt
#   - output/review/shot_52_portrait/candidates.json
#   - output/review/shot_52_portrait/pexels_b.jpg
#   - output/review/shot_52_portrait/pexels_a.jpg
#   - output/review/shot_25_archive/pexels_c.jpg
#   - output/review/shot_25_archive/context.txt
#   - output/review/shot_25_archive/candidates.json
#   - output/review/shot_25_archive/pexels_b.jpg
#   - output/review/shot_25_archive/pexels_a.jpg
#   - output/review/shot_38_archive/pexels_c.jpg
#   - output/review/shot_38_archive/context.txt
#   - output/review/shot_38_archive/candidates.json
#   - output/review/shot_38_archive/pexels_b.jpg
#   - output/review/shot_38_archive/pexels_a.jpg
#   - output/review/shot_41_location/pexels_c.jpg
#   - output/review/shot_41_location/context.txt
#   - output/review/shot_41_location/candidates.json
#   - output/review/shot_41_location/pexels_b.jpg
#   - output/review/shot_41_location/pexels_a.jpg
#   - output/review/shot_32_broll/pexels_c.jpg
#   - output/review/shot_32_broll/context.txt
#   - output/review/shot_32_broll/candidates.json
#   - output/review/shot_32_broll/pexels_b.jpg
#   - output/review/shot_32_broll/pexels_a.jpg
#   - output/review/shot_45_portrait/pexels_c.jpg
#   - output/review/shot_45_portrait/context.txt
#   - output/review/shot_45_portrait/candidates.json
#   - output/review/shot_45_portrait/pexels_b.jpg
#   - output/review/shot_45_portrait/pexels_a.jpg
#   - output/review/shot_55_broll/pexels_c.jpg
#   - output/review/shot_55_broll/context.txt
#   - output/review/shot_55_broll/candidates.json
#   - output/review/shot_55_broll/pexels_b.jpg
#   - output/review/shot_55_broll/pexels_a.jpg
#   - output/review/overrides/character.jpg
#   - output/review/overrides/book_cover.jpg
#   - output/review/shot_11_location/pexels_c.jpg
#   - output/review/shot_11_location/context.txt
#   - output/review/shot_11_location/candidates.json
#   - output/review/shot_11_location/pexels_b.jpg
#   - output/review/shot_11_location/pexels_a.jpg
#   - output/review/shot_21_broll/pexels_c.jpg
#   - output/review/shot_21_broll/context.txt
#   - output/review/shot_21_broll/candidates.json
#   - output/review/shot_21_broll/pexels_b.jpg
#   - output/review/shot_21_broll/pexels_a.jpg

# %%
# Standalone test runner
# !python verify_user_marked.py
# Out:
# INFO    verify  ── regex tests ──
# INFO    verify  regex: 13 cases, 0 failed
# INFO    verify  ── resolution tests ──
# INFO    phase3.sources.decisions  Shot 5: user-marked file hit my_jafar.jpg
# INFO    phase3.sources.decisions  Shot 16: pinned-portrait hit character.jpg
# INFO    phase3.sources.decisions  Shot 28: chosen-file hit pexels_b.jpg
# INFO    phase3.sources.decisions  Shot 44: user-marked file hit User_Map.PNG
# INFO    verify  resolution: 4 scenarios, 0 failed
# INFO    verify  ✓ All checks passed

# %%
# !python verify_title_card.py --book-cover my_book.jpg
# Out:
# INFO    verify4  ── typography ──
# INFO    phase3.typography_common  Amiri fonts loaded via repo fonts/ (next to phase3): /content/fonts
# Traceback (most recent call last):
#   File "/content/verify_title_card.py", line 150, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/verify_title_card.py", line 142, in main
#     log.info("── typography ──"); check_typography()
#                                   ^^^^^^^^^^^^^^^^^^
#   File "/content/verify_title_card.py", line 36, in check_typography
#     assert t.GOLD_AGED == (200, 162, 74), f"GOLD_AGED has wrong value: {t.GOLD_AGED}"
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: GOLD_AGED has wrong value: (200, 131, 74)

# %%
# !python diagnose_issue4.py --review-dir output/review/   # is everything in place?
# Out:
# ── typography.py ──
# Amiri fonts loaded via repo fonts/ (next to phase3): /content/fonts
#   loaded from: /content/phase3/typography.py
#   ✓ GOLD_AGED constant present: (200, 131, 74)
#   ✓ TypographySpec.cover_image present
#   ✓ TypographySpec.accent_color present
# Traceback (most recent call last):
#   File "/content/diagnose_issue4.py", line 309, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/diagnose_issue4.py", line 285, in main
#     typo_ok    = check_typography_patched()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/diagnose_issue4.py", line 59, in check_typography_patched
#     title_main = t.SIZES.get("title_main")
#                  ^^^^^^^
# AttributeError: module 'phase3.typography' has no attribute 'SIZES'

# %%
import os

# Step 3: user reviews output/review/ — opens decisions.json, swaps a
# few `chosen_url` values, drops shot_03.jpg / shot_38.jpg overrides.

# Step 4: render — render_plan.py reads the decisions file
# The --review-dir argument consumes user's choices
# !python render_plan.py \
--plan         output/al_askari_plan_v2.json \
--audio        output/al_askari_audio.mp3 \
--review-dir   output/review/ \
--book-cover-fit contain \
--output       output/final_cut_C.mp4 \
--no-captions \
--typography-family C \
> output/render.log 2>&1 &

print("Rendering begins ...")
# Out:
# Rendering begins ...

# %%
# Monitor rendering progress
import time
from IPython.display import clear_output

log_path = "output/render.log"

print("Monitoring rendering progress...")
while True:
    try:
        # Read the log file contents
        try:
            with open(log_path, "r") as f:
                log_content = f.read()
        except FileNotFoundError:
            log_content = ""

        # Clear cell output and show the last 20 lines
        clear_output(wait=True)
        lines = log_content.splitlines()
        print("\n".join(lines[-20:]))

        # Check if the script's success signature is in the log
        if "Done in" in log_content or "Rendered video →" in log_content:
            print("\n✅ Rendering process completed successfully! Stopped monitoring.")
            break

        time.sleep(5)

    except KeyboardInterrupt:
        print("\n⚠️ Monitoring stopped manually. The script may still be running.")
        break
# Out:
#   [█████████████████████░░░░░░░░░]  71%  shot 58/61: typography                                                INFO  phase3.sources.decisions  Shot 59: pinned-portrait hit character.jpg
# INFO  phase3.sources  Shot 59: review-dossier hit character.jpg
# INFO  phase3.render  Shot 59: using fetched image from user_upload
# INFO  phase3.render  [render 73%] shot 59/61: portrait
#
#   [█████████████████████░░░░░░░░░]  72%  shot 59/61: portrait                                                  INFO  phase3.render  [render 74%] shot 60/61: typography
#
#   [██████████████████████░░░░░░░░]  73%  shot 60/61: typography                                                INFO  phase3.render  [render 75%] shot 61/61: title_card
#
#   [██████████████████████░░░░░░░░]  75%  shot 61/61: title_card                                                INFO  phase3.render  [render 80%] concat all shots
#
#   [████████████████████████░░░░░░]  80%  concat all shots                                                      INFO  phase3.render  [render 92%] mux audio and captions
#
#   [███████████████████████████░░░]  92%  mux audio and captions                                                INFO  phase3.render  [render 100%] done
#
#   [██████████████████████████████] 100%  done
# INFO  phase3.render  Rendered video → output/final_cut_B.mp4
#
# Done in 983s  —  output/final_cut_B.mp4  (32.9 MB)
#
# ✅ Rendering process completed successfully! Stopped monitoring.

# %%
# !python diagnose_captions.py --plan output/al_askari_plan_v2.json   # inspect actual ASS events
# Out:
# render.py loaded from : /content/phase3/render.py
# GAP in source         : 0.15
# MIN_VISIBLE in source : 0.6
#
# plan                  : output/al_askari_plan_v2.json  (61 shots)
# events parsed         : 27
#
#   #    start      end   span  gap_from_prev  lines  text (first 50 chars)
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   1    4.060    8.490  4.430                     2  من أجل تحرير وطنه، ⏎ لكنه اكتشفَ أنَّ أشرس الأعداء
#   2   13.760   19.030  5.270        +5.270s      2  بل شهادةٌ حيّةٌ من قلب ⏎ أحداثٍ غيّرت وجهَ المنطقة …
#   3   24.540   29.680  5.140        +5.510s      1  سقوط الدولة العثمانية وميلاد الحركة القومية العربي…
#   4   42.650   50.630  7.980       +12.970s      2  أعطته الكتائب والحلم بوطن مستقل؟ هذه ⏎ الأسئلة تحتل…
#   5   55.430   59.390  3.960        +4.800s      1  يبدأ جعفر العسكري رحلته من الموصل سنة ١٩٠٤،
#   6   59.690   64.250  4.560        +0.300s      2  حين غادر وطنه الأول ⏎ إلى الاستانة لينضم إلى الكلية
#   7   64.550   70.520  5.970        +0.300s      2  العسكرية العثمانية لم تكن هذه ⏎ مجرد رحلة جغرافية، …
#   8   82.540   89.340  6.800       +12.020s      2  في الدولة العثمانية في قاعات الكلية العسكرية، ⏎ الت…
#   9   96.630  103.080  6.450        +7.290s      2  من خلال الحداثة والمعرفة ⏎ العسكرية الأوروبية كانت …
#  10  103.380  110.060  6.680        +0.300s      2  آنذاك تحت قيادة محمود شوكت باشا، ⏎ الذي سعى جاهداً …
#  11  133.440  141.190  7.750       +23.380s      2  آمن أن التعليم والجيش الحديث يمكنهما ⏎ أن يكونا أدا…
#  12  146.350  150.660  4.310        +5.160s      1  مع اقتراب جعفر من أوساط السلطة والعمل السياسي،
#  13  163.390  169.250  5.860       +12.730s      2  الشهير، الذي أطاح بالسلطان عبدالحميد الثاني، ⏎ كان …
#  14  169.550  176.940  7.390        +0.300s      2  عليه وربما مشاركاً فيه رأى بعينيه كيف ⏎ يمكن لقوة ع…
#  15  183.400  192.100  8.700        +6.460s      2  التحرر الفكري والتطلع الأوروبي لم يكن ⏎ كافياً لتحط…
#
# Gaps (first 14): min=0.300s  avg=6.914s  max=23.380s
# Wrapped events: 12/15 have an explicit \N break
#
# ✓ Gaps ~0.30s AND captions wrapped cleanly — v3.2 PATCH IS LIVE.

# %%
# Zip output files for exporting
import os
import zipfile

output_dir = 'output'
zip_filename = 'output_files.zip'

# Get all files in the output directory
files_to_zip = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]

# Filter out the .mp3 file
filtered_files = [f for f in files_to_zip if not f.endswith('.mp3')]

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file_path in filtered_files:
        # Add file to zip, preserving directory structure relative to 'output_dir'
        zipf.write(file_path, os.path.relpath(file_path, output_dir))

print(f"🤐 Successfully created '{zip_filename}' containing: ")
for f in filtered_files:
    print(f"  - {f}")
# Out:
# 🤐 Successfully created 'output_files.zip' containing:
#   - output/final_cut_B.mp4
#   - output/render.log
#   - output/al_askari_plan_v2.json
#   - output/planner_raw_response.txt
#   - output/word_timings.json

# %%
# Save zipped file to Drive
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# Define the destination directory and file path
dest_dir = '/content/drive/MyDrive/_Phase3'
dest_file_path = os.path.join(dest_dir, 'output_files.zip')

# Create the destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)
print(f"Destination directory '{dest_dir}' ensured to exist.")

# --- Test write access to the directory ---
test_file = os.path.join(dest_dir, 'test_write.txt')
try:
    with open(test_file, 'w') as f:
        f.write('This is a test file.\n')
    print(f"✅ Successfully wrote test file to '{test_file}'.")
    os.remove(test_file) # Clean up the test file
    print(f"Test file '{test_file}' removed.")
except Exception as e:
    print(f"Error writing test file to '{test_file}': {e}")
    print("⚠️ It seems there might be a permissions or access issue with Google Drive.")
    # Exit or raise an error if write access fails
    raise
# ----------------------------------------

shutil.copy('/content/output_files.zip', dest_file_path)
print(f"📽️ rough_cut.mp4 saved to Google Drive at '{dest_file_path}'.")
# Out:
# Mounted at /content/drive
# Destination directory '/content/drive/MyDrive/_Phase3' ensured to exist.
# ✅ Successfully wrote test file to '/content/drive/MyDrive/_Phase3/test_write.txt'.
# Test file '/content/drive/MyDrive/_Phase3/test_write.txt' removed.
# 📽️ rough_cut.mp4 saved to Google Drive at '/content/drive/MyDrive/_Phase3/output_files.zip'.
